# %% [markdown]
# ### Importing all the libraries

# %%
from huggingface_hub import list_datasets 
import requests
import pandas as pd
import numpy as np
import requests
import logging
import json
from pathlib import Path
import os

# %%
# from datasets import list_datasets
all_datasets = list(list_datasets())

# %%
columns = ['id', 'author', 'sha','created_at','tzinfo','last_modified','private','gated','disabled','downloads','downloads_all_time','paperswithcode_id',
'tags','trending_score','card_data','siblings']
 
df = pd.DataFrame(all_datasets, columns=columns)

# %%
df.head(5)
# Out:
#                             id      author  \
# 0  fka/awesome-chatgpt-prompts         fka
# 1           neuralwork/arxiver  neuralwork
# 2               Spawning/PD12M    Spawning
# 3                vikhyatk/lofi    vikhyatk
# 4             BAAI/Infinity-MM        BAAI
#
#                                         sha                created_at  tzinfo  \
# 0  459a66186f8f83020117b8acc5ff5af69fc95b45 2022-12-13 23:47:45+00:00     NaN
# 1  698a6662e77fd5dd45dbbec988abc8123e5fa086 2024-10-14 12:21:13+00:00     NaN
# 2  4fd5d707a72aad71bd88c7e7bc5df2ae5e0d6c53 2024-09-26 18:20:09+00:00     NaN
# 3  966a2d3065aac26c0385b4ef2d50983c0429a305 2024-07-27 05:11:44+00:00     NaN
# 4  b08f9598c80831566701ce64a9661b01714acf19 2024-10-15 07:51:48+00:00     NaN
#
#               last_modified  private  gated  disabled  downloads  \
# 0 2024-09-03 21:28:41+00:00    False  False     False       7927
# 1 2024-11-01 21:18:04+00:00    False  False     False       3357
# 2 2024-10-31 15:25:49+00:00    False  False     False       2783
# 3 2024-10-26 20:42:55+00:00    False  False     False       2351
# 4 2024-10-29 10:41:29+00:00    False   auto     False      31450
#
#   downloads_all_time paperswithcode_id  \
# 0               None              None
# 1               None              None
# 2               None              None
# 3               None              None
# 4               None              None
#
#                                                 tags  trending_score  \
# 0  [task_categories:question-answering, license:c...           109.0
# 1  [license:cc-by-nc-sa-4.0, size_categories:10K<...            66.0
# 2  [language:en, license:cdla-permissive-2.0, siz...            62.0
# 3  [license:cc-by-nc-4.0, size_categories:100K<n<...            34.0
# 4  [task_categories:image-to-text, language:en, l...            34.0
#
#   card_data siblings
# 0      None     None
# 1      None     None
# 2      None     None
# 3      None     None
# 4      None     None

# %% [markdown]
# #### HuggingFace: Total datasets are 2,30,446.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237595 entries, 0 to 237594
# Data columns (total 16 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  237595 non-null  object
#  1   author              237595 non-null  object
#  2   sha                 237595 non-null  object
#  3   created_at          237595 non-null  datetime64[ns, UTC]
#  4   tzinfo              0 non-null       float64
#  5   last_modified       237595 non-null  datetime64[ns, UTC]
#  6   private             237595 non-null  bool
#  7   gated               237595 non-null  object
#  8   disabled            237595 non-null  bool
#  9   downloads           237595 non-null  int64
#  10  downloads_all_time  0 non-null       object
#  11  paperswithcode_id   1067 non-null    object
#  12  tags                237595 non-null  object
#  13  trending_score      237595 non-null  float64
#  14  card_data           0 non-null       object
#  15  siblings            0 non-null       object
# dtypes: bool(2), datetime64[ns, UTC](2), float64(2), int64(1), object(9)
# memory usage: 25.8+ MB

# %% [markdown]
# #### Getting the list of datasets id.

# %%
datasets_ids = df['id'].tolist()
datasets_ids
# Out:
# ['fka/awesome-chatgpt-prompts',
#  'neuralwork/arxiver',
#  'Spawning/PD12M',
#  'vikhyatk/lofi',
#  'BAAI/Infinity-MM',
#  'GAIR/o1-journey',
#  'marcelbinz/Psych-101',
#  'amphion/Emilia-Dataset',
#  'neulab/PangeaInstruct',
#  'BAAI/Infinity-Instruct',
#  'ajibawa-2023/Software-Architecture',
#  'wikimedia/wikipedia',
#  'HuggingFaceH4/ultrachat_200k',
#  'allenai/dolma',
#  'mlabonne/orpo-dpo-mix-40k',
#  'upstage/dp-bench',
#  'nvidia/HelpSteer2',
#  'wyu1/Leopard-Instruct',
#  'Amod/mental_health_counseling_conversations',
#  'nkp37/OpenVid-1M',
#  'nvidia/OpenMathInstruct-2',
#  'opencsg/chinese-fineweb-edu-v2',
#  'qq8933/OpenLongCoT-Pretrain',
#  'HuggingFaceTB/smollm-corpus',
#  'Vikhrmodels/GrandMaster-PRO-MAX',
#  'google/frames-benchmark',
#  'saheedniyi/naijaweb',
#  'dyyyyyyyy/ScaleQuest-Math',
#  'Zyphra/dclm-dedup',
#  'beomi/KoAlpaca-RealQA',
#  'roneneldan/TinyStories',
#  'HuggingFaceH4/ultrafeedback_binarized',
#  'microsoft/orca-math-word-problems-200k',
#  'CohereForAI/aya_collection_language_split',
#  'TIGER-Lab/WebInstructSub',
#  'neulab/MultiUI',
#  'abisee/cnn_dailymail',
#  'rajpurkar/squad',
#  'Salesforce/wikitext',
#  'allenai/c4',
#  'codeparrot/github-code',
#  'Open-Orca/OpenOrca',
#  'lavita/ChatDoctor-HealthCareMagic-100k',
#  'lmsys/lmsys-chat-1m',
#  'allenai/tulu-v2-sft-mixture',
#  'CohereForAI/aya_collection',
#  'Zihan1004/FNSPID',
#  'gretelai/synthetic_text_to_sql',
#  'HuggingFaceFW/fineweb',
#  'SkunkworksAI/reasoning-0.01',
#  'Zyphra/Zyda-2',
#  'argilla/Synth-APIGen-v0.1',
#  'SylvanL/Traditional-Chinese-Medicine-Dataset-SFT',
#  'PULSE-ECG/ECGBench',
#  'fancyzhx/ag_news',
#  'Anthropic/hh-rlhf',
#  'rubend18/ChatGPT-Jailbreak-Prompts',
#  'McAuley-Lab/Amazon-Reviews-2023',
#  'CohereForAI/aya_dataset',
#  'HuggingFaceFW/fineweb-edu',
#  'Salesforce/xlam-function-calling-60k',
#  'HuggingFaceM4/Docmatix',
#  'lmms-lab/LLaVA-Video-178K',
#  'OpenGVLab/OmniCorpus-CC',
#  'MLBtrio/genz-slang-dataset',
#  'NerdyRodent/NR-Flux-ComfyUI-Workflows',
#  'Skywork/Skywork-Reward-Preference-80K-v0.2',
#  'Koala-36M/Koala-36M-v1',
#  'walkerhyf/NCSSD',
#  'khaled123/Tunisian_Dialectic_English_Derja',
#  'deepghs/reddit_mostlyhumans_full',
#  'Rowan/hellaswag',
#  'stanfordnlp/imdb',
#  'rajpurkar/squad_v2',
#  'openai/gsm8k',
#  'google/fleurs',
#  'mozilla-foundation/common_voice_11_0',
#  'yahma/alpaca-cleaned',
#  'anon8231489123/ShareGPT_Vicuna_unfiltered',
#  'vicgalle/alpaca-gpt4',
#  'cerebras/SlimPajama-627B',
#  'meta-math/MetaMathQA',
#  'OpenGVLab/MVBench',
#  'ruslanmv/ai-medical-chatbot',
#  'MedRAG/pubmed',
#  'm-a-p/Code-Feedback',
#  'allenai/WildChat-1M',
#  'OpenGVLab/ShareGPT-4o',
#  'mlfoundations/dclm-baseline-1.0',
#  'proj-persona/PersonaHub',
#  'AI-MO/NuminaMath-CoT',
#  'OpenGVLab/OmniCorpus-YT',
#  'THUDM/LongCite-45k',
#  'C4AI-Community/multilingual-reward-bench',
#  'openai/MMMLU',
#  'BAAI/CCI3-HQ',
#  'KingNish/reasoning-base-20k',
#  'worldcuisines/food-kb',
#  'worldcuisines/vqa',
#  'Turkish-NLI/legal_nli_TR_V1',
#  'Marqo/marqo-GS-10M',
#  'openfoodfacts/product-database',
#  'Spawning/PD3M',
#  'PULSE-ECG/ECGInstruct',
#  'tokyotech-llm/lmsys-chat-1m-synth',
#  'Rapidata/flux1.1-likert-scale-preference',
#  'lt-asset/REPOCOD',
#  'tau/commonsense_qa',
#  'li2017dailydialog/daily_dialog',
#  'google-research-datasets/mbpp',
#  'openai/openai_humaneval',
#  'Helsinki-NLP/opus-100',
#  'Helsinki-NLP/opus_books',
#  'ccdv/pubmed-summarization',
#  'codeparrot/apps',
#  'CShorten/ML-ArXiv-Papers',
#  'deepmind/code_contests',
#  'ds4sd/DocLayNet',
#  'derek-thomas/ScienceQA',
#  'tatsu-lab/alpaca',
#  'mozilla-foundation/common_voice_13_0',
#  'shareAI/ShareGPT-Chinese-English-90k',
#  'liuhaotian/LLaVA-Instruct-150K',
#  'liuhaotian/LLaVA-Pretrain',
#  'tiiuae/falcon-refinedweb',
#  'tasksource/oasst1_pairwise_rlhf_reward',
#  'shibing624/medical',
#  'beomi/KoAlpaca-v1.1a',
#  'iamtarun/python_code_instructions_18k_alpaca',
#  'ds4sd/DocLayNet-v1.1',
#  'bitext/Bitext-customer-support-llm-chatbot-training-dataset',
#  'TIGER-Lab/MathInstruct',
#  'glaiveai/glaive-code-assistant',
#  'Duxiaoman-DI/FinCorpus',
#  'openbmb/UltraFeedback',
#  'HuggingFaceH4/no_robots',
#  'nvidia/HelpSteer',
#  'PatronusAI/financebench',
#  'b3x0m/Chinese-H-Novels',
#  'Idavidrein/gpqa',
#  'argilla/ultrafeedback-binarized-preferences-cleaned',
#  'peiyi9979/Math-Shepherd',
#  'allenai/reward-bench',
#  'nyanko7/danbooru2023',
#  'AGBonnet/augmented-clinical-notes',
#  'argilla/OpenHermesPreferences',
#  'bigcode/the-stack-v2',
#  'SakanaAI/JA-VG-VQA-500',
#  'mozilla-foundation/common_voice_17_0',
#  'rootsautomation/ScreenSpot',
#  'Real-IAD/Real-IAD',
#  'bigcode/self-oss-instruct-sc2-exec-filter-50k',
#  'CortexLM/midjourney-v6',
#  'FBK-MT/Speech-MASSIVE',
#  'JailbreakBench/JBB-Behaviors',
#  'allenai/wildjailbreak',
#  'arcee-ai/The-Tome',
#  'cnamuangtoun/resume-job-description-fit',
#  'yingyingzhang/metamath-qwen2-math',
#  'allmalab/aze-books',
#  'opencsg/chinese-fineweb-edu',
#  'OpenGVLab/OmniCorpus-CC-210M',
#  'therem/CLEAR',
#  'KbsdJames/Omni-MATH',
#  'BAAI/IndustryCorpus2',
#  'nyuuzyou/chatgpt-in-russia-qa',
#  'amphora/krx-sample-instructions',
#  'WaveGenAI/youtube-cc-by-music',
#  'openbmb/VisRAG-Ret-Train-Synthetic-data',
#  'mengfang/MATH-APS',
#  'amazon/AmazonQAC',
#  'mlabonne/open-perfectblend',
#  'DEVAI-benchmark/DEVAI',
#  'fairchem/OMAT24',
#  'sam-paech/gutenberg3-generalfiction-scifi-fantasy-romance-adventure-dpo',
#  'SoftMINER-Group/CulturalKaleidoscope',
#  'qq8933/OpenLongCoT-SFT',
#  'louisbrulenaudet/lemone-docs-embedded',
#  'PleIAs/ToxicCommons',
#  'DynaMath/DynaMath_Sample',
#  'hewei2001/ReachQA',
#  'sergioburdisso/news_media_bias_and_factuality',
#  'ToastyPigeon/skein-text-adventures',
#  'ailsntua/Chordonomicon',
#  '5CD-AI/Viet-Table-Markdown',
#  'tblard/allocine',
#  'arxiv-community/arxiv_dataset',
#  'bookcorpus/bookcorpus',
#  'microsoft/cats_vs_dogs',
#  'statmt/cc100',
#  'code-search-net/code_search_net',
#  'cais/mmlu',
#  'hotpotqa/hotpot_qa',
#  'jhu-clsp/jfleg',
#  'legacy-datasets/mc4',
#  'ylecun/mnist',
#  'google-research-datasets/natural_questions',
#  'Skylion007/openwebtext',
#  'cornell-movie-review-data/rotten_tomatoes',
#  'aps/super_glue',
#  'HDLTex/web_of_science',
#  'legacy-datasets/wikipedia',
#  'Yelp/yelp_review_full',
#  'huggingface/documentation-images',
#  'SetFit/amazon_reviews_multi_en',
#  'google-research-datasets/conceptual_captions',
#  'ILSVRC/imagenet-1k',
#  'openlifescienceai/medmcqa',
#  'facebook/voxpopuli',
#  'facebook/flores',
#  'edinburghcstr/ami',
#  'wushan/vehicle_qa',
#  'ShapeNet/ShapeNetCore',
#  'zeroshot/twitter-financial-news-sentiment',
#  'joelniklaus/Multi_Legal_Pile',
#  'bigcode/the-stack',
#  'KGraph/FB15k-237',
#  'nguyenvulebinh/song_dataset',
#  'TheFusion21/PokemonCards',
#  'EleutherAI/the_pile_deduplicated',
#  'liwu/MNBVC',
#  'Isotonic/human_assistant_conversation',
#  'QingyiSi/Alpaca-CoT',
#  'axiong/pmc_oa',
#  'NiGuLa/Russian_Sensitive_Topics',
#  'databricks/databricks-dolly-15k',
#  'kunishou/databricks-dolly-15k-ja',
#  'OpenAssistant/oasst1',
#  'liyucheng/zhihu_rlhf_3k',
#  'liuhaotian/LLaVA-CC3M-Pretrain-595K',
#  'b-mc2/sql-create-context',
#  'howard-hou/OCR-VQA',
#  'kz-transformers/multidomain-kazakh-dataset',
#  'bigcode/governance-card',
#  'michaelwzhu/ShenNong_TCM_Dataset',
#  'silk-road/alpaca-data-gpt4-chinese',
#  'FreedomIntelligence/HuatuoGPT-sft-data-v1',
#  'timdettmers/openassistant-guanaco',
#  'Birchlabs/openai-prm800k-stepwise-critic',
#  'tabtoyou/KoLLaVA-Instruct-150k',
#  'kaist-ai/CoT-Collection',
#  'GAIR/lima',
#  'maharshipandya/spotify-tracks-dataset',
#  'Glavin001/startup-interviews',
#  'nickrosh/Evol-Instruct-Code-80k-v1',
#  'theblackcat102/evol-codealpaca-v1',
#  'shibing624/sharegpt_gpt4',
#  'medarc/pubmed',
#  'THUDM/LongBench',
#  'garage-bAInd/Open-Platypus',
#  'greengerong/leetcode',
#  'MuskumPillerum/General-Knowledge',
#  'google/dreambooth',
#  'Falah/image_generation_prompts_SDXL',
#  'allenai/MADLAD-400',
#  'twang2218/chinese-law-and-regulations',
#  'facebook/belebele',
#  'qgyd2021/chinese_ner_sft',
#  'chats-bug/input_tools_plans',
#  'open-web-math/open-web-math',
#  'manu/project_gutenberg',
#  're-align/just-eval-instruct',
#  'wuliangfo/Chinese-Pixiv-Novel',
#  'Orion-zhen/pixiv-novel',
#  'Intuit-GenSRF/sexting-nsfw-adultconten',
#  'FreedomIntelligence/Evol-Instruct-Chinese-GPT4',
#  'CropNet/CropNet',
#  'princeton-nlp/SWE-bench',
#  'OpenPipe/hacker-news',
#  'gaia-benchmark/GAIA',
#  'togethercomputer/RedPajama-Data-V2',
#  'mpingale/mental-health-chat-dataset',
#  'joujiboi/japanese-anime-speech',
#  'teknium/OpenHermes-2.5',
#  'locuslab/TOFU',
#  'EDS-lab/electricity-demand',
#  'neuralwork/fashion-style-instruct',
#  'MMMU/MMMU',
#  'Anthropic/discrim-eval',
#  'BAAI/TACO',
#  'HuggingFaceM4/WebSight',
#  'argilla/distilabel-intel-orca-dpo-pairs',
#  'jondurbin/gutenberg-dpo-v0.1',
#  'u-haru/malicious_logs',
#  'WhiteRabbitNeo/Code-Functions-Level-General',
#  'AlekseyKorshuk/evol-codealpaca-v1-dpo',
#  'math-ai/TemplateGSM',
#  'mythicinfinity/libritts_r',
#  'ibrahimhamamci/CT-RATE',
#  'espnet/yodas',
#  'upstage/Pretraining_Dataset',
#  'CyberNative/Code_Vulnerability_Security_DPO',
#  'JJinho/pubmed_articles',
#  'Shitao/bge-m3-data',
#  'talkmap/telecom-conversation-corpus',
#  'Luffy503/VoCo-10k',
#  'xwjzds/hr_multiwoz_tod_sgd',
#  'vikhyatk/lnqa',
#  'victor/hf-spaces-with-descriptions',
#  'kooshan/Astrology-B',
#  'japanese-asr/ja_asr.reazonspeech_test',
#  'issai/kazqad',
#  'wenbopan/Chinese-dpo-pairs',
#  'Anthropic/persuasion',
#  'heegyu/ko-openchat-0404-test',
#  'HuggingFaceM4/the_cauldron',
#  'BothBosu/Scammer-Conversation',
#  'lytang/LLM-AggreFact',
#  'naklecha/minecraft-question-answer-700k',
#  'hfl/ruozhiba_gpt4',
#  'nvidia/ChatRAG-Bench',
#  'Anas989898/Vision-OCR-Financial-Reports-10k',
#  'lara-martin/FIREBALL',
#  'TIGER-Lab/MMLU-Pro',
#  'Replete-AI/code_bagel',
#  'lmms-lab/LLaVA-ReCap-118K',
#  'ShareGPT4Video/ShareGPT4Video',
#  'Yongxin-Guo/VTG-IT',
#  'lmms-lab/LLaVA-ReCap-558K',
#  'HuggingFaceFW/fineweb-edu-score-2',
#  'mlabonne/harmful_behaviors',
#  'cis-lmu/GlotCC-V1',
#  'nyu-visionx/Cambrian-10M',
#  'mdwiratathya/ROCO-radiology',
#  'UCSC-VLAA/MedTrinity-25M',
#  'laolao77/MMDU',
#  'namkoong-lab/PersonalLLM',
#  'ServiceNow-AI/M2Lingual',
#  'OpenGVLab/GUI-Odyssey',
#  'OEvortex/EmotionalIntelligence-10K',
#  'nyu-visionx/CV-Bench',
#  'ViliamVolosV/russian_classic_literature',
#  'SPACENOS/exbot-nsfw-sexting',
#  'CaptionEmporium/coyo-hd-11m-llavanext',
#  'Magpie-Align/Magpie-Qwen2-Pro-300K-Filtered',
#  'xinlai/Math-Step-DPO-10K',
#  'Magpie-Align/Magpie-Qwen2-Pro-200K-Chinese',
#  'lmms-lab/M4-Instruct-Data',
#  'QuietImpostor/Claude-3-Opus-Claude-3.5-Sonnnet-9k',
#  'OpenFace-CQUPT/FaceCaption-15M',
#  'naijavoices/naijavoices-dataset',
#  'SmartGitiCorp/persian_tts',
#  'CaptionEmporium/midjourney-niji-1m-llavanext',
#  'visual-layer/imagenet-1k-vl-enriched',
#  'nothingiisreal/Claude-3-Opus-Instruct-15K',
#  'stanford-oval/ccnews',
#  'PleIAs/WTO-PDF',
#  'PleIAs/AMF-PDF',
#  'mrzjy/kaomoji_caption',
#  'watashihakobashi/ogiri',
#  'grider-withourai/nekopara-speech',
#  'airtrain-ai/fineweb-edu-fortified',
#  'kalomaze/Opus_Instruct_25k',
#  'Nopm/Opus_WritingStruct',
#  'argilla/magpie-ultra-v0.1',
#  'cfahlgren1/hub-stats',
#  'ThePioneer/japanese-photos',
#  'mlabonne/FineTome-100k',
#  'kms7530/ko-coco-bal',
#  'Vikhrmodels/Grounded-RAG-RU-v2',
#  'THUDM/LongWriter-6k',
#  'princeton-nlp/SWE-bench_Verified',
#  'Qingyun/llava_v1_5_fewshot_sft',
#  'allenai/OLMoE-mix-0924',
#  'Dusker/chinese-laws-pretrain',
#  'DataFog/medical-transcription-instruct',
#  'Team-ACE/ToolACE',
#  'Magpie-Align/Magpie-Llama-3.1-Pro-MT-500K-v0.1',
#  'ai-lab/MBD-mini',
#  'CaptionEmporium/flickr-megalith-10m-internvl2-multi-caption',
#  'gaianet/learn-rust',
#  'Joon007/science-feedback',
#  'allganize/RAG-Evaluation-Dataset-JA',
#  'vidore/colpali_train_set',
#  'TommyChien/UltraDomain',
#  'lmarena-ai/PPE-Human-Preference-V1',
#  'channelcorp/KoMagpie-raw',
#  'wjbmattingly/catmus-qwen2-vl',
#  'allenai/multipref',
#  'HuggingFaceFV/finevideo',
#  'LooksJuicy/Chinese-Roleplay-Novel',
#  'DominiqueBrunato/TRACE-it_CALAMITA',
#  'LooksJuicy/Chinese-Emotional-Intelligence',
#  'homebrewltd/instruction-text-only-full',
#  'autonomousvision/PDM_Lite_Carla_LB2',
#  'homebrewltd/mixed-instruction-speech-whispervq-v3-full',
#  'opencsg/chinese-cosmopedia',
#  'mistralai/MM-MT-Bench',
#  'yeates/PromptfixData',
#  'BAAI/IndustryInstruction',
#  'reach-vb/gguf-stats',
#  'davanstrien/ufo-ColPali',
#  'llm-lab/TuringQ',
#  'RANEPA-ai/SLAVA-OpenData-2800-v1',
#  'Maple728/Time-300B',
#  'TIGER-Lab/WebInstructFull',
#  'k-mktr/improved-flux-prompts-photoreal-portrait',
#  'nguyendv02/ViMD_Dataset',
#  'LiveXiv/LiveXiv',
#  'openbmb/VisRAG-Ret-Train-In-domain-data',
#  'meghas/fact_check_data',
#  'princeton-nlp/prolong-data-512K',
#  'argilla-warehouse/apigen-synth-trl',
#  'LLM360/TxT360',
#  'Sin2pi/JA_audio_EN_text_tedx_18k',
#  'rombodawg/Everything_Instruct_Multilingual',
#  'big-banyan-tree/BBT_CommonCrawl_2024',
#  'replit/agent-challenge',
#  'litagin/Galgame_Speech_ASR_16kHz',
#  'AntiplagiatCompany/CL4Lang',
#  'Cartinoe5930/web_text_synthetic_dataset_50k',
#  'dmis-lab/ChroKnowBench',
#  'Gryphe/Sonnet3.5-SlimOrcaDedupCleaned-20k',
#  'lt-asset/collu-bench',
#  'microsoft/TemporalBench',
#  'ChuGyouk/CompositionalGSM_augmented',
#  'AIML-TUDA/CLEVR-Sudoku',
#  'USTC-KnowledgeComputingLab/ElectrolyteBench',
#  'xhwl/cruxeval-x',
#  'ajrogier/llm-ideology-analysis',
#  'sam-paech/gutenbergs_1_2_3_antislop-dpo',
#  'z-hb/OpenSatMap',
#  'THUDM/LongReward-10k',
#  'united-we-care/United-Syn-Med',
#  'juliozhao/DocSynth300K',
#  'mertcobanov/animals',
#  'OpenDFM/MobA-MobBench',
#  'takara-ai/FloodNet_2021-Track_2_Dataset_HF',
#  'baijs/AudioSetCaps',
#  'Laxhar/danbooru_4M_pixel_resort',
#  'CohereForAI/m-ArenaHard',
#  'twodgirl/suppress-layers-in-sd3.5',
#  'yale-nlp/M3SciQA',
#  'ClovenDoug/150k_keyphrases_labelled',
#  'AlidarAsvarov/lez-rus-books',
#  'pls2000/pixiv20161029_20241026_monthly_rank_1_50',
#  'Pankaj8922/Text-corp',
#  'OALL/ALRAGE-Benchmark-sprint-results',
#  'ylacombe/globe_processed',
#  'DN-Erazora/ShinkaiGAN_Dataset',
#  'asigalov61/South-Park',
#  'DeepNLP/Human-Preferences-Alignment-KTO-Dataset-AI-Services-Genuine-User-Reviews',
#  'AIDX-ktds/ko_leaderboard',
#  'hpprc/aozora-yomi',
#  'nyuuzyou/ppt4web',
#  'Reza8848/AAAR-1.0',
#  'MilaWang/SpatialEval',
#  'asigalov61/Pub-Piano-MIDI-Dataset',
#  'YueDataset/RefRef',
#  'StarQuestLab/oxford-iiit-pet',
#  'UCLNLP/adversarial_qa',
#  'Yale-LILY/aeslc',
#  'nwu-ctext/afrikaans_ner_corpus',
#  'allenai/ai2_arc',
#  'google/air_dialogue',
#  'fancyzhx/amazon_polarity',
#  'defunct-datasets/amazon_us_reviews',
#  'legacy-datasets/ami',
#  'facebook/anli',
#  'deepmind/aqua_rat',
#  'halabi2016/arabic_speech_corpus',
#  'hsseinmz/arcd',
#  'facebook/asset',
#  'legacy-datasets/banking77',
#  'AI-Lab-Makerere/beans',
#  'nectec/best2009',
#  'FiscalNote/billsum',
#  'TheBritishLibrary/blbooks',
#  'ParlAI/blended_skill_talk',
#  'nyu-mll/blimp',
#  'barilan/blog_authorship_corpus',
#  'google/boolq',
#  'UFRGS/brwac',
#  'ryo0634/bsd_ja_en',
#  'legacy-datasets/c4',
#  'china-ai-law-challenge/cail2018',
#  'cam-cst/cbt',
#  'google-research-datasets/cfq',
#  'uoft-cs/cifar10',
#  'uoft-cs/cifar100',
#  'google-research-datasets/circa',
#  'google/civil_comments',
#  'tdiggelm/climate_fever',
#  'clinc/clinc_oos',
#  'clue/clue',
#  'jaredfern/codah',
#  'google/code_x_glue_cc_clone_detection_big_clone_bench',
#  'google/code_x_glue_cc_clone_detection_poj104',
#  'google/code_x_glue_cc_defect_detection',
#  'google/code_x_glue_ct_code_to_text',
#  'speechbrain/common_language',
#  'legacy-datasets/common_voice',
#  'hendrycks/competition_math',
#  'conceptnet5/conceptnet5',
#  'eriktks/conll2003',
#  'CFPB/consumer-finance-complaints',
#  'stanfordnlp/coqa',
#  'cornell-movie-dialog/cornell_movie_dialog',
#  'facebook/covost2',
#  'rishitdagli/cppe-5',
#  'stanfordnlp/craigslist_bargains',
#  'microsoft/crd3',
#  'theatticusproject/cuad-qa',
#  'community-datasets/definite_pronoun_resolution',
#  'community-datasets/disaster_response_messages',
#  'google-research-datasets/disfl_qa',
#  'thunlp/docred',
#  'ucinlp/drop',
#  'AUEB-NLP/ecthr_cases',
#  'SemEvalWorkshop/emo',
#  'dair-ai/emotion',
#  'facebook/empathetic_dialogues',
#  'iamollas/ethos',
#  'community-datasets/europa_eac_tm',
#  'Helsinki-NLP/europarl',
#  'mhardalov/exams',
#  'zalando-datasets/fashion_mnist',
#  'takala/financial_phrasebank',
#  'ethz/food101',
#  'GEM/gem',
#  'community-datasets/generics_kb',
#  'nyu-mll/glue',
#  'google-research-datasets/go_emotions',
#  'Efstathios/guardian_authorship',
#  'ImperialCollegeLondon/health_fact',
#  'SemEvalWorkshop/hyperpartisan_news_detection',
#  'iapp/iapp_wiki_qa_squad',
#  'ai4bharat/indic_glue',
#  'indonlp/indonlu',
#  'thu-coai/kd_conv_with_kb',
#  'Helsinki-NLP/kde4',
#  'facebook/kilt_tasks',
#  'facebook/kilt_wikipedia',
#  'klue/klue',
#  'inmoonlight/kor_hate',
#  'kakaobrain/kor_nli',
#  'facebook/lama',
#  'cimec/lambada',
#  'coastalcph/lex_glue',
#  'openslr/librispeech_asr',
#  'lince-benchmark/lince',
#  'keithito/lj_speech',
#  'billion-word-benchmark/lm1b',
#  'cis-lmu/m_lama',
#  'deepmind/math_dataset',
#  'allenai/math_qa',
#  'UCSD26/medical_dialog',
#  'apple/mkqa',
#  'microsoft/ms_marco',
#  'levow/msra_ner',
#  'IWSLT/mt_eng_vietnamese',
#  'nyu-mll/multi_nli',
#  'pfb30/multi_woz_v22',
#  'deepmind/narrativeqa',
#  'google-research-datasets/nq_open',
#  'malmaud/onestop_qa',
#  'Helsinki-NLP/open_subtitles',
#  'allenai/openbookqa',
#  'oscar-corpus/oscar',
#  'google-research-datasets/paws',
#  'peixiang/pec',
#  'peoples-daily-ner/peoples_daily_ner',
#  'deepmind/pg19',
#  'ybisk/piqa',
#  'ncbi/pubmed',
#  'qiaojin/PubMedQA',
#  'allenai/qasc',
#  'allenai/qasper',
#  'quora-competitions/quora',
#  'ehovy/race',
#  'mbien/recipe_nlg',
#  'kdexd/red_caps',
#  'webis/tldr-17',
#  'ucirvine/reuters21578',
#  'allenai/ropes',
#  'Samsung/samsum',
#  'kuznetsoffandrey/sberquad',
#  'airesearch/scb_mt_enth_2020',
#  'google-research-datasets/schema_guided_dstc8',
#  'armanc/scientific_papers',
#  'allenai/scifact',
#  'allenai/sciq',
#  'kyunghyuncho/search_qa',
#  'ucirvine/sms_spam',
#  'stanfordnlp/snli',
#  'allenai/social_bias_frames',
#  'google/speech_commands',
#  'xlangai/spider',
#  'crux82/squad_it',
#  'KorQuAD/squad_kor_v1',
#  'KorQuAD/squad_kor_v2',
#  'stanfordnlp/sst',
#  'PhilipMay/stsb_multi_mt',
#  'megagonlabs/subjqa',
#  'ufldl-stanford/svhn',
#  'allenai/swag',
#  'community-datasets/swahili_news',
#  'rcds/swiss_judgment_prediction',
#  'community-datasets/tashkeela',
#  'google-research-datasets/taskmaster2',
#  'Helsinki-NLP/tatoeba',
#  'tmu-nlp/thai_toxicity_tweet',
#  'EleutherAI/pile',
#  'karpathy/tiny_shakespeare',
#  'CogComp/trec',
#  'mandarjoshi/trivia_qa',
#  'savasy/ttc4900',
#  'fthbrmnby/turkish_product_reviews',
#  'cardiffnlp/tweet_eval',
#  'google-research-datasets/tydiqa',
#  'CSTR-Edinburgh/vctk',
#  'hltcoe/weibo_ner',
#  'bea2019st/wi_locness',
#  'CUHK-CSE/wider_face',
#  'google/wiki40b',
#  'michaelauli/wiki_bio',
#  'facebook/wiki_dpr',
#  'microsoft/wiki_qa',
#  'unimelb-nlp/wikiann',
#  'Salesforce/wikisql',
#  'allenai/winogrande',
#  'wmt/wmt14',
#  'wmt/wmt19',
#  'cambridgeltl/xcopa',
#  'google/xquad',
#  'EdinburghNLP/xsum',
#  'google/xtreme',
#  'community-datasets/yahoo_answers_topics',
#  'fancyzhx/yelp_polarity',
#  'AI-Sweden/SuperLim',
#  'Abirate/english_quotes',
#  'adorkin/extended_tweet_emojis',
#  'AlekseyKorshuk/comedy-scripts',
#  'Babelscape/wikineural',
#  'CAiRE/ASCEND',
#  'Nexdata/accented_english',
#  'DiFronzo/Human_Activity_Recognition',
#  'Emanuel/UD_Portuguese-Bosque',
#  'Fraser/dream-coder',
#  'GEM/ART',
#  'GEM/totto',
#  'GEM/wiki_auto_asset_turk',
#  'GonzaloA/fake_news',
#  'Helsinki-NLP/tatoeba_mt',
#  'KTH/nst',
#  'NbAiLab/norwegian_parliament',
#  'Paul/hatecheck',
#  'PaulLerner/viquae_wikipedia',
#  'PlanTL-GOB-ES/SQAC',
#  'PlanTL-GOB-ES/cantemist-ner',
#  'SetFit/20_newsgroups',
#  'SetFit/ag_news',
#  'SetFit/emotion',
#  'SetFit/go_emotions',
#  'SetFit/hate_speech_offensive',
#  'SetFit/sst2',
#  'SetFit/sst5',
#  'SetFit/subj',
#  'SetFit/tweet_sentiment_extraction',
#  'SoLID/shellcode_i_a32',
#  'SocialGrep/one-million-reddit-confessions',
#  'Tevatron/wikipedia-nq-corpus',
#  'ai4bharat/samanantar',
#  'albertvillanova/legal_contracts',
#  'albertvillanova/tests-raw-jsonl',
#  'alistvt/coqa-stories',
#  'andstor/smart_contracts',
#  'maastrichtlawtech/bsard',
#  'bavard/personachat_truecased',
#  'bazinga/bazinga',
#  'bigscience/P3',
#  'bs-modeling-metadata/c4-en-html-with-metadata',
#  'castorini/afriberta-corpus',
#  'ccdv/arxiv-classification',
#  'ccdv/arxiv-summarization',
#  'ccdv/cnn_dailymail',
#  'ccdv/govreport-summarization',
#  'clips/mfaq',
#  'clips/mqa',
#  'csebuetnlp/xlsum',
#  'dalle-mini/open-images',
#  'dynabench/dynasent',
#  'espejelomar/code_search_net_python_10000_examples',
#  'facebook/multilingual_librispeech',
#  'flax-sentence-embeddings/stackexchange_math_jsonl',
#  'gabtan99/pex-conversations',
#  'gpt3mix/sst2',
#  'gsarti/clean_mc4_it',
#  'gsarti/flores_101',
#  'hf-internal-testing/librispeech_asr_dummy',
#  'huggingartists/kendrick-lamar',
#  'huggingartists/mf-doom',
#  'huggingartists/young-thug',
#  'iarfmoose/qa_evaluator',
#  'iarfmoose/question_generator',
#  'imvladikon/hebrew_speech_kan',
#  'jfrenz/legalglue',
#  'jgammack/SAE-door-abstracts',
#  'jglaser/binding_affinity',
#  'jsfactory/mental_health_reddit_posts',
#  'kiyoung2/aistage-mrc',
#  'lara-martin/Scifi_TV_Shows',
#  'lewtun/drug-reviews',
#  'lewtun/github-issues',
#  'limjiayi/hateful_memes_expanded',
#  'liweili/c4_200m',
#  'lukesjordan/worldbank-project-documents',
#  'luozhouyang/dureader',
#  'codeparrot/codeparrot-clean',
#  'maydogan/TRSAv1',
#  'mishig/sample_images',
#  'ml6team/cnn_dailymail_nl',
#  'ml6team/xsum_nl',
#  'mostol/wiktionary-ipa',
#  'mozilla-foundation/common_voice_8_0',
#  'nateraw/fairface',
#  'ncduy/mt-en-vi',
#  'nferruz/UR50_2021_04',
#  'nickmuchi/trade-the-event-finance',
#  'nthngdy/ccnews_split',
#  'ought/raft',
#  'pile-of-law/pile-of-law',
#  'pmc/open_access',
#  'qanastek/ELRC-Medical-V2',
#  'qanastek/EMEA-V3',
#  'qanastek/WMT-16-PubMed',
#  'rahular/itihasa',
#  'sentence-transformers/embedding-training-data',
#  'sentence-transformers/reddit-title-body',
#  'shibing624/source_code',
#  'shivam/hindi_pib_processed',
#  'sil-ai/bloom-lm',
#  'solomonk/reddit_mental_health_posts',
#  'stas/openwebtext-10k',
#  'svakulenk0/qrecc',
#  'tau/scrolls',
#  'teven/stackexchange',
#  'tharindu/SOLID',
#  'transformersbook/codeparrot',
#  'turingbench/TuringBench',
#  'ucberkeley-dlab/measuring-hate-speech',
#  'unicamp-dl/mmarco',
#  'wikimedia/wikisource',
#  'winvoker/turkish-sentiment-analysis-dataset',
#  'z-uo/female-LJSpeech-italian',
#  'zapsdcn/citation_intent',
#  'zhoujun/hitab',
#  'huggan/anime-faces',
#  'nlpaueb/finer-139',
#  'google/xtreme_s',
#  'laion/relaion2B-en-research-safe',
#  'laion/relaion2B-multi-research-safe',
#  'Azu/Handwritten-Mathematical-Expression-Convert-LaTeX',
#  'McGill-NLP/feedbackQA',
#  'gigant/horse2zebra',
#  'ctheodoris/Genecorpus-30M',
#  'SetFit/amazon_reviews_multi_ja',
#  'SetFit/amazon_reviews_multi_zh',
#  'stjokerli/TextToText_wsc_seqio',
#  'Stanford/wikitablequestions',
#  'marsyas/gtzan',
#  'tomekkorbak/pile-curse-chunk-16',
#  'yhavinga/ccmatrix',
#  'Monash-University/monash_tsf',
#  'emrecan/nli_tr_for_simcse',
#  'nthngdy/oscar-small',
#  'Georgii/russianPoetry',
#  'blo05/cleaned_wiki_en_0-20',
#  'huggan/CelebA-faces-with-attributes',
#  'huggan/few-shot-dog',
#  'huggan/few-shot-art-painting',
#  'jamescalam/stoic-corpus',
#  'copenlu/fever_gold_evidence',
#  'marksverdhei/wordnet-definitions-en-2021',
#  'somosnlp-hackathon-2022/spanish-to-quechua',
#  'huggan/flowers-102-categories',
#  'SocialGrep/the-reddit-dataset-dataset',
#  'PolyAI/minds14',
#  'julien-c/impressionists',
#  'huggan/wikiart',
#  'chainyo/rvl-cdip-invoice',
#  'bible-nlp/biblenlp-corpus',
#  'skt/kobest_v1',
#  'huggingnft/cryptopunks',
#  'arampacha/rsicd',
#  'vicenteor/sbu_captions',
#  'vinaykudari/acled-information-extraction',
#  'patriziobellan/PET',
#  'mwong/fever-claim-related',
#  'Divyanshu/indicxnli',
#  'KevinZ/oLMpics',
#  'stepp1/tweet_emotion_intensity',
#  'bigscience-historical-texts/Open_Medieval_French',
#  'mteb/stackoverflowdupquestions-reranking',
#  'mteb/sickr-sts',
#  'enoriega/GENIA-Term-Corpus',
#  'ranjaykrishna/visual_genome',
#  'aharley/rvl_cdip',
#  'laion/clevr-webdataset',
#  'McGill-NLP/FaithDial',
#  'blinoff/kinopoisk',
#  'chrisjay/crowd-speech-africa',
#  'toxigen/toxigen-data',
#  'google/wit',
#  'wikimedia/wit_base',
#  'facebook/textvqa',
#  'Fhrozen/FSD50k',
#  'laion/laion-high-resolution',
#  'HugoLaurencon/libri_light',
#  'HuggingFaceM4/charades',
#  'pere/italian_tweets_500k',
#  'LIUM/tedlium',
#  'Team-PIXEL/rendered-wikipedia-english',
#  'tdros/corals',
#  'mteb/amazon_massive_intent',
#  'mwritescode/slither-audited-smart-contracts',
#  'wdc/products-2017',
#  'mteb/banking77',
#  'WorkInTheDark/FairytaleQA',
#  'Yoonseong/climatebert_factcheck',
#  'strombergnlp/nlpcc-stance',
#  'HuggingFaceM4/yttemporal180m',
#  'laion/laion2B-en-aesthetic',
#  'laion/laion1B-nolang-aesthetic',
#  'laion/laion-art',
#  'NLPC-UOM/sentence_alignment_dataset-Sinhala-Tamil-English',
#  'Voicemod/librispeech40',
#  'mteb/amazon_reviews_multi',
#  'mteb/amazon_polarity',
#  'mteb/tweet_sentiment_extraction',
#  'sileod/movie_recommendation',
#  'ganchengguang/resume_seven_class',
#  'mteb/sts22-crosslingual-sts',
#  'angie-chen55/python-github-code',
#  'LTCB/enwik8',
#  'lmqg/qg_koquad',
#  'limsc/fr-nfr-classification',
#  'BeIR/msmarco',
#  'BeIR/hotpotqa',
#  'Adapting/empathetic_dialogues_v2',
#  'ziq/depression_advice',
#  'momilla/flattened_contract_4tools',
#  'yoshitomo-matsubara/srsd-feynman_hard',
#  'AhmedSSabir/Japanese-wiki-dump-sentence-dataset',
#  'truthfulqa/truthful_qa',
#  'florentgbelidji/car-reviews',
#  'google/bigbench',
#  'Bingsu/Human_Action_Recognition',
#  'google/quickdraw',
#  'sil-ai/bloom-speech',
#  'speechcolab/gigaspeech',
#  'AlekseyKorshuk/erotic-books',
#  'SetFit/CR',
#  'stanfordnlp/sst2',
#  'demo-org/auditor_review',
#  'spencer/software_slacks',
#  'thu-coai/lccc',
#  'ITESM/embedded_faqs_medicare',
#  'angie-chen55/javascript-github-code',
#  'amanbawa96/jsonDataset',
#  'julien-c/kaggle-hugomathien-soccer',
#  'valurank/Adult-content-dataset',
#  'mounikaiiith/Telugu-Sarcasm',
#  'HuggingFaceM4/Stanford-Cars',
#  'Shayanvsf/pquad_public',
#  'Nexdata/Cantonese_Conversational_Speech_Data_by_Mobile_Phone_and_Voice_Recorder',
#  'iejMac/CLIP-Kinetics700',
#  'Nexdata/Far-filed_Noise_Speech_Data_in_Home_Environment_by_Mic-Array',
#  'Nexdata/Emotional_Video_Data',
#  'nateraw/parti-prompts',
#  'fever/feverous',
#  'stanfordnlp/concurrentqa',
#  'joelniklaus/brazilian_court_decisions',
#  'rkstgr/mtg-jamendo',
#  'HuggingFaceM4/VQAv2',
#  'codeparrot/codecomplex',
#  'Nexdata/Human_Facial_Skin_Defects_Data',
#  'pfin123/hindi-aggregated',
#  'knkarthick/dialogsum',
#  'christopher/rosetta-code',
#  'launch/open_question_type',
#  'knkarthick/samsum',
#  'kensho/spgispeech',
#  'codeparrot/github-code-clean',
#  'madao33/new-title-chinese',
#  'zh-plus/tiny-imagenet',
#  'benschill/brain-tumor-collection',
#  'FIdo-AI/ua-news',
#  'nreimers/reddit_question_best_answers',
#  'codeparrot/xlcost-text-to-code',
#  'Zaib/java-vulnerability',
#  'elihoole/asrs-aviation-reports',
#  'demelin/moral_stories',
#  'hita/social-behavior-emotions',
#  'naver-clova-ix/cord-v1',
#  'nreimers/reddit_question_best_answers_langs',
#  'rajistics/indian_food_images',
#  'tner/mit_movie_trivia',
#  'tner/mit_restaurant',
#  'jvanz/portuguese_sentiment_analysis',
#  'ceyda/fashion-products-small',
#  'Muennighoff/xwinograd',
#  'clapika2010/infotab',
#  'naver-clova-ix/cord-v2',
#  'naver-clova-ix/synthdog-ja',
#  'joelniklaus/mapa',
#  'FinanceInc/auditor_sentiment',
#  'Artificio/WikiArt',
#  'bhadresh-savani/photo-to-cartoon',
#  'ttxy/emotion',
#  'kiddothe2b/contract-nli',
#  'psyche/synonyms_ko',
#  'okite97/news-data',
#  'Aimlab/Sentiment-Analysis-Roman-Urdu',
#  'davanstrien/pytorchmodelmetadata',
#  'jordiae/exebench',
#  'AI-Growth-Lab/patents_claims_1.5m_traim_test',
#  'joelniklaus/lextreme',
#  'ziwenyd/transcoder-geeksforgeeks',
#  'daekeun-ml/naver-news-summarization-ko',
#  'Corran/pexelvideos',
#  'owaiskha9654/PubMed_MultiLabel_Text_Classification_Dataset_MeSH',
#  'Bingsu/laion2B-multi-korean-subset',
#  'rungalileo/medical_transcription_40',
#  'snoop2head/enron_aeslc_emails',
#  'NX2411/AIhub-korean-speech-data-large',
#  'podbilabs/synthdog-podbi-pl',
#  'nielsr/docvqa_1200_examples_donut',
#  'dali-does/clevr-math',
#  'pcuenq/oxford-pets',
#  'scikit-learn/churn-prediction',
#  'hoskinson-center/proof-pile',
#  'SLPL/syntran-fa',
#  'UCL-DARK/ludwig',
#  'juletxara/visual-spatial-reasoning',
#  'laion/aesthetics_v2_4.75',
#  'RUCAIBox/Story-Generation',
#  'allenai/nllb',
#  'Bingsu/zeroth-korean',
#  'iohadrubin/wikitext-103-raw-v1',
#  'AhmedSSoliman/CodeXGLUE-CONCODE',
#  'GateNLP/broad_twitter_corpus',
#  'sepidmnorozy/Uyghur_sentiment',
#  'sepidmnorozy/Cantonese_sentiment',
#  'sepidmnorozy/Korean_sentiment',
#  'sepidmnorozy/Vietnamese_sentiment',
#  'MLCommons/peoples_speech',
#  'laion/aesthetics_v2_4.5',
#  'allenai/real-toxicity-prompts',
#  'ariesutiono/entailment-bank-v3',
#  'tyqiangz/multilingual-sentiments',
#  'csebuetnlp/BanglaNMT',
#  'harshitkaran/Hindi',
#  'masakhane/mafand',
#  'RCC-MSU/collection3',
#  'ai-forever/Peter',
#  'kakaobrain/coyo-700m',
#  'iejMac/CLIP-WebVid',
#  'ShapeNet/ShapeNetSem-archive',
#  'yuntian-deng/im2latex-100k',
#  'hf-internal-testing/diffusers-images',
#  'demo-org/diabetes',
#  'ShapeNet/shapenetcore-glb',
#  'fusing/wikiart_captions',
#  'SamAct/medium_cleaned',
#  'bigbio/biosses',
#  'priyank-m/chinese_text_recognition',
#  'Leli1024/Race-processed',
#  'priyank-m/IAM_words_text_recognition',
#  'zeroshot/twitter-financial-news-topic',
#  'jonathanli/law-stack-exchange',
#  'ai-forever/school_notebooks_RU',
#  'pysentimiento/spanish-tweets',
#  'cannlytics/cannabis_results',
#  'opentargets/clinical_trial_reason_to_stop',
#  'dclure/laion-aesthetics-12m-umap',
#  'ntcuong777/ubuntu_dialogue_corpus_train',
#  'lambdalabs/pokemon-blip-captions',
#  'mrmoor/cyber-threat-intelligence',
#  'Bingsu/openwebtext_20p',
#  'psyche/korean_idioms',
#  'skytnt/fbanimehq',
#  'Gustavosta/Stable-Diffusion-Prompts',
#  'rajistics/electricity_demand',
#  'TheGreatRambler/mm2_user',
#  'yerevann/coco-karpathy',
#  'kejian/codesearchnet-python-pep8-v1',
#  'kejian/codesearchnet-python-raw-457k',
#  'THUDM/humaneval-x',
#  'nlp-guild/medical-data',
#  'yuntian-deng/im2ly',
#  'melismeric/spotify_song_album_covers',
#  'biomegix/soap-notes',
#  'detection-datasets/fashionpedia',
#  'detection-datasets/fashionpedia_4_categories',
#  'bccnf/NER-portugues-shuffled',
#  'dbal0503/Bundesliga',
#  'ashraq/esc50',
#  'eliwill/Stoic-dataset',
#  'marcmaxmeister/unitarian-universalist-sermons',
#  ...]

# %%
def get_datasetids_HF():
    # from datasets import list_datasets
    all_datasets = list_datasets()
    datasetid_list = list(all_datasets)
    #columns defined from HF datasets
    columns = ['id', 'author', 'sha','created_at','tzinfo','last_modified','private','gated','disabled','downloads','downloads_all_time','paperswithcode_id',
    'tags','trending_score','card_data','siblings']

    #converting to dataframe for detailed and readable information
    df = pd.DataFrame(datasetid_list, columns=columns)
    datasets_ids = df['id'].tolist()
    return datasets_ids

# %%
get_datasetids_HF()
# Out:
# ['fka/awesome-chatgpt-prompts',
#  'neuralwork/arxiver',
#  'Spawning/PD12M',
#  'vikhyatk/lofi',
#  'BAAI/Infinity-MM',
#  'GAIR/o1-journey',
#  'marcelbinz/Psych-101',
#  'amphion/Emilia-Dataset',
#  'neulab/PangeaInstruct',
#  'BAAI/Infinity-Instruct',
#  'ajibawa-2023/Software-Architecture',
#  'wikimedia/wikipedia',
#  'HuggingFaceH4/ultrachat_200k',
#  'allenai/dolma',
#  'mlabonne/orpo-dpo-mix-40k',
#  'upstage/dp-bench',
#  'nvidia/HelpSteer2',
#  'wyu1/Leopard-Instruct',
#  'Amod/mental_health_counseling_conversations',
#  'nkp37/OpenVid-1M',
#  'nvidia/OpenMathInstruct-2',
#  'opencsg/chinese-fineweb-edu-v2',
#  'qq8933/OpenLongCoT-Pretrain',
#  'HuggingFaceTB/smollm-corpus',
#  'Vikhrmodels/GrandMaster-PRO-MAX',
#  'google/frames-benchmark',
#  'saheedniyi/naijaweb',
#  'dyyyyyyyy/ScaleQuest-Math',
#  'Zyphra/dclm-dedup',
#  'beomi/KoAlpaca-RealQA',
#  'roneneldan/TinyStories',
#  'HuggingFaceH4/ultrafeedback_binarized',
#  'microsoft/orca-math-word-problems-200k',
#  'CohereForAI/aya_collection_language_split',
#  'TIGER-Lab/WebInstructSub',
#  'neulab/MultiUI',
#  'abisee/cnn_dailymail',
#  'rajpurkar/squad',
#  'Salesforce/wikitext',
#  'allenai/c4',
#  'codeparrot/github-code',
#  'Open-Orca/OpenOrca',
#  'lavita/ChatDoctor-HealthCareMagic-100k',
#  'lmsys/lmsys-chat-1m',
#  'allenai/tulu-v2-sft-mixture',
#  'CohereForAI/aya_collection',
#  'Zihan1004/FNSPID',
#  'gretelai/synthetic_text_to_sql',
#  'HuggingFaceFW/fineweb',
#  'SkunkworksAI/reasoning-0.01',
#  'Zyphra/Zyda-2',
#  'argilla/Synth-APIGen-v0.1',
#  'SylvanL/Traditional-Chinese-Medicine-Dataset-SFT',
#  'PULSE-ECG/ECGBench',
#  'fancyzhx/ag_news',
#  'Anthropic/hh-rlhf',
#  'rubend18/ChatGPT-Jailbreak-Prompts',
#  'McAuley-Lab/Amazon-Reviews-2023',
#  'CohereForAI/aya_dataset',
#  'HuggingFaceFW/fineweb-edu',
#  'Salesforce/xlam-function-calling-60k',
#  'HuggingFaceM4/Docmatix',
#  'lmms-lab/LLaVA-Video-178K',
#  'OpenGVLab/OmniCorpus-CC',
#  'MLBtrio/genz-slang-dataset',
#  'NerdyRodent/NR-Flux-ComfyUI-Workflows',
#  'Skywork/Skywork-Reward-Preference-80K-v0.2',
#  'Koala-36M/Koala-36M-v1',
#  'walkerhyf/NCSSD',
#  'khaled123/Tunisian_Dialectic_English_Derja',
#  'deepghs/reddit_mostlyhumans_full',
#  'Rowan/hellaswag',
#  'stanfordnlp/imdb',
#  'rajpurkar/squad_v2',
#  'openai/gsm8k',
#  'google/fleurs',
#  'mozilla-foundation/common_voice_11_0',
#  'yahma/alpaca-cleaned',
#  'anon8231489123/ShareGPT_Vicuna_unfiltered',
#  'vicgalle/alpaca-gpt4',
#  'cerebras/SlimPajama-627B',
#  'meta-math/MetaMathQA',
#  'OpenGVLab/MVBench',
#  'ruslanmv/ai-medical-chatbot',
#  'MedRAG/pubmed',
#  'm-a-p/Code-Feedback',
#  'allenai/WildChat-1M',
#  'OpenGVLab/ShareGPT-4o',
#  'mlfoundations/dclm-baseline-1.0',
#  'proj-persona/PersonaHub',
#  'AI-MO/NuminaMath-CoT',
#  'OpenGVLab/OmniCorpus-YT',
#  'THUDM/LongCite-45k',
#  'C4AI-Community/multilingual-reward-bench',
#  'openai/MMMLU',
#  'BAAI/CCI3-HQ',
#  'KingNish/reasoning-base-20k',
#  'worldcuisines/food-kb',
#  'worldcuisines/vqa',
#  'Turkish-NLI/legal_nli_TR_V1',
#  'Marqo/marqo-GS-10M',
#  'openfoodfacts/product-database',
#  'Spawning/PD3M',
#  'PULSE-ECG/ECGInstruct',
#  'tokyotech-llm/lmsys-chat-1m-synth',
#  'Rapidata/flux1.1-likert-scale-preference',
#  'lt-asset/REPOCOD',
#  'tau/commonsense_qa',
#  'li2017dailydialog/daily_dialog',
#  'google-research-datasets/mbpp',
#  'openai/openai_humaneval',
#  'Helsinki-NLP/opus-100',
#  'Helsinki-NLP/opus_books',
#  'ccdv/pubmed-summarization',
#  'codeparrot/apps',
#  'CShorten/ML-ArXiv-Papers',
#  'deepmind/code_contests',
#  'ds4sd/DocLayNet',
#  'derek-thomas/ScienceQA',
#  'tatsu-lab/alpaca',
#  'mozilla-foundation/common_voice_13_0',
#  'shareAI/ShareGPT-Chinese-English-90k',
#  'liuhaotian/LLaVA-Instruct-150K',
#  'liuhaotian/LLaVA-Pretrain',
#  'tiiuae/falcon-refinedweb',
#  'tasksource/oasst1_pairwise_rlhf_reward',
#  'shibing624/medical',
#  'beomi/KoAlpaca-v1.1a',
#  'iamtarun/python_code_instructions_18k_alpaca',
#  'ds4sd/DocLayNet-v1.1',
#  'bitext/Bitext-customer-support-llm-chatbot-training-dataset',
#  'TIGER-Lab/MathInstruct',
#  'glaiveai/glaive-code-assistant',
#  'Duxiaoman-DI/FinCorpus',
#  'openbmb/UltraFeedback',
#  'HuggingFaceH4/no_robots',
#  'nvidia/HelpSteer',
#  'PatronusAI/financebench',
#  'b3x0m/Chinese-H-Novels',
#  'Idavidrein/gpqa',
#  'argilla/ultrafeedback-binarized-preferences-cleaned',
#  'peiyi9979/Math-Shepherd',
#  'allenai/reward-bench',
#  'nyanko7/danbooru2023',
#  'AGBonnet/augmented-clinical-notes',
#  'argilla/OpenHermesPreferences',
#  'bigcode/the-stack-v2',
#  'SakanaAI/JA-VG-VQA-500',
#  'mozilla-foundation/common_voice_17_0',
#  'rootsautomation/ScreenSpot',
#  'Real-IAD/Real-IAD',
#  'bigcode/self-oss-instruct-sc2-exec-filter-50k',
#  'CortexLM/midjourney-v6',
#  'FBK-MT/Speech-MASSIVE',
#  'JailbreakBench/JBB-Behaviors',
#  'allenai/wildjailbreak',
#  'arcee-ai/The-Tome',
#  'cnamuangtoun/resume-job-description-fit',
#  'yingyingzhang/metamath-qwen2-math',
#  'allmalab/aze-books',
#  'opencsg/chinese-fineweb-edu',
#  'OpenGVLab/OmniCorpus-CC-210M',
#  'therem/CLEAR',
#  'KbsdJames/Omni-MATH',
#  'BAAI/IndustryCorpus2',
#  'nyuuzyou/chatgpt-in-russia-qa',
#  'amphora/krx-sample-instructions',
#  'WaveGenAI/youtube-cc-by-music',
#  'openbmb/VisRAG-Ret-Train-Synthetic-data',
#  'mengfang/MATH-APS',
#  'amazon/AmazonQAC',
#  'mlabonne/open-perfectblend',
#  'DEVAI-benchmark/DEVAI',
#  'fairchem/OMAT24',
#  'sam-paech/gutenberg3-generalfiction-scifi-fantasy-romance-adventure-dpo',
#  'SoftMINER-Group/CulturalKaleidoscope',
#  'qq8933/OpenLongCoT-SFT',
#  'louisbrulenaudet/lemone-docs-embedded',
#  'PleIAs/ToxicCommons',
#  'DynaMath/DynaMath_Sample',
#  'hewei2001/ReachQA',
#  'sergioburdisso/news_media_bias_and_factuality',
#  'ToastyPigeon/skein-text-adventures',
#  'ailsntua/Chordonomicon',
#  '5CD-AI/Viet-Table-Markdown',
#  'tblard/allocine',
#  'arxiv-community/arxiv_dataset',
#  'bookcorpus/bookcorpus',
#  'microsoft/cats_vs_dogs',
#  'statmt/cc100',
#  'code-search-net/code_search_net',
#  'cais/mmlu',
#  'hotpotqa/hotpot_qa',
#  'jhu-clsp/jfleg',
#  'legacy-datasets/mc4',
#  'ylecun/mnist',
#  'google-research-datasets/natural_questions',
#  'Skylion007/openwebtext',
#  'cornell-movie-review-data/rotten_tomatoes',
#  'aps/super_glue',
#  'HDLTex/web_of_science',
#  'legacy-datasets/wikipedia',
#  'Yelp/yelp_review_full',
#  'huggingface/documentation-images',
#  'SetFit/amazon_reviews_multi_en',
#  'google-research-datasets/conceptual_captions',
#  'ILSVRC/imagenet-1k',
#  'openlifescienceai/medmcqa',
#  'facebook/voxpopuli',
#  'facebook/flores',
#  'edinburghcstr/ami',
#  'wushan/vehicle_qa',
#  'ShapeNet/ShapeNetCore',
#  'zeroshot/twitter-financial-news-sentiment',
#  'joelniklaus/Multi_Legal_Pile',
#  'bigcode/the-stack',
#  'KGraph/FB15k-237',
#  'nguyenvulebinh/song_dataset',
#  'TheFusion21/PokemonCards',
#  'EleutherAI/the_pile_deduplicated',
#  'liwu/MNBVC',
#  'Isotonic/human_assistant_conversation',
#  'QingyiSi/Alpaca-CoT',
#  'axiong/pmc_oa',
#  'NiGuLa/Russian_Sensitive_Topics',
#  'databricks/databricks-dolly-15k',
#  'kunishou/databricks-dolly-15k-ja',
#  'OpenAssistant/oasst1',
#  'liyucheng/zhihu_rlhf_3k',
#  'liuhaotian/LLaVA-CC3M-Pretrain-595K',
#  'b-mc2/sql-create-context',
#  'howard-hou/OCR-VQA',
#  'kz-transformers/multidomain-kazakh-dataset',
#  'bigcode/governance-card',
#  'michaelwzhu/ShenNong_TCM_Dataset',
#  'silk-road/alpaca-data-gpt4-chinese',
#  'FreedomIntelligence/HuatuoGPT-sft-data-v1',
#  'timdettmers/openassistant-guanaco',
#  'Birchlabs/openai-prm800k-stepwise-critic',
#  'tabtoyou/KoLLaVA-Instruct-150k',
#  'kaist-ai/CoT-Collection',
#  'GAIR/lima',
#  'maharshipandya/spotify-tracks-dataset',
#  'Glavin001/startup-interviews',
#  'nickrosh/Evol-Instruct-Code-80k-v1',
#  'theblackcat102/evol-codealpaca-v1',
#  'shibing624/sharegpt_gpt4',
#  'medarc/pubmed',
#  'THUDM/LongBench',
#  'garage-bAInd/Open-Platypus',
#  'greengerong/leetcode',
#  'MuskumPillerum/General-Knowledge',
#  'google/dreambooth',
#  'Falah/image_generation_prompts_SDXL',
#  'allenai/MADLAD-400',
#  'twang2218/chinese-law-and-regulations',
#  'facebook/belebele',
#  'qgyd2021/chinese_ner_sft',
#  'chats-bug/input_tools_plans',
#  'open-web-math/open-web-math',
#  'manu/project_gutenberg',
#  're-align/just-eval-instruct',
#  'wuliangfo/Chinese-Pixiv-Novel',
#  'Orion-zhen/pixiv-novel',
#  'Intuit-GenSRF/sexting-nsfw-adultconten',
#  'FreedomIntelligence/Evol-Instruct-Chinese-GPT4',
#  'CropNet/CropNet',
#  'princeton-nlp/SWE-bench',
#  'OpenPipe/hacker-news',
#  'gaia-benchmark/GAIA',
#  'togethercomputer/RedPajama-Data-V2',
#  'mpingale/mental-health-chat-dataset',
#  'joujiboi/japanese-anime-speech',
#  'teknium/OpenHermes-2.5',
#  'locuslab/TOFU',
#  'EDS-lab/electricity-demand',
#  'neuralwork/fashion-style-instruct',
#  'MMMU/MMMU',
#  'Anthropic/discrim-eval',
#  'BAAI/TACO',
#  'HuggingFaceM4/WebSight',
#  'argilla/distilabel-intel-orca-dpo-pairs',
#  'jondurbin/gutenberg-dpo-v0.1',
#  'u-haru/malicious_logs',
#  'WhiteRabbitNeo/Code-Functions-Level-General',
#  'AlekseyKorshuk/evol-codealpaca-v1-dpo',
#  'math-ai/TemplateGSM',
#  'mythicinfinity/libritts_r',
#  'ibrahimhamamci/CT-RATE',
#  'espnet/yodas',
#  'upstage/Pretraining_Dataset',
#  'CyberNative/Code_Vulnerability_Security_DPO',
#  'JJinho/pubmed_articles',
#  'Shitao/bge-m3-data',
#  'talkmap/telecom-conversation-corpus',
#  'Luffy503/VoCo-10k',
#  'xwjzds/hr_multiwoz_tod_sgd',
#  'vikhyatk/lnqa',
#  'victor/hf-spaces-with-descriptions',
#  'kooshan/Astrology-B',
#  'japanese-asr/ja_asr.reazonspeech_test',
#  'issai/kazqad',
#  'wenbopan/Chinese-dpo-pairs',
#  'Anthropic/persuasion',
#  'heegyu/ko-openchat-0404-test',
#  'HuggingFaceM4/the_cauldron',
#  'BothBosu/Scammer-Conversation',
#  'lytang/LLM-AggreFact',
#  'naklecha/minecraft-question-answer-700k',
#  'hfl/ruozhiba_gpt4',
#  'nvidia/ChatRAG-Bench',
#  'Anas989898/Vision-OCR-Financial-Reports-10k',
#  'lara-martin/FIREBALL',
#  'TIGER-Lab/MMLU-Pro',
#  'Replete-AI/code_bagel',
#  'lmms-lab/LLaVA-ReCap-118K',
#  'ShareGPT4Video/ShareGPT4Video',
#  'Yongxin-Guo/VTG-IT',
#  'lmms-lab/LLaVA-ReCap-558K',
#  'HuggingFaceFW/fineweb-edu-score-2',
#  'mlabonne/harmful_behaviors',
#  'cis-lmu/GlotCC-V1',
#  'nyu-visionx/Cambrian-10M',
#  'mdwiratathya/ROCO-radiology',
#  'UCSC-VLAA/MedTrinity-25M',
#  'laolao77/MMDU',
#  'namkoong-lab/PersonalLLM',
#  'ServiceNow-AI/M2Lingual',
#  'OpenGVLab/GUI-Odyssey',
#  'OEvortex/EmotionalIntelligence-10K',
#  'nyu-visionx/CV-Bench',
#  'ViliamVolosV/russian_classic_literature',
#  'SPACENOS/exbot-nsfw-sexting',
#  'CaptionEmporium/coyo-hd-11m-llavanext',
#  'Magpie-Align/Magpie-Qwen2-Pro-300K-Filtered',
#  'xinlai/Math-Step-DPO-10K',
#  'Magpie-Align/Magpie-Qwen2-Pro-200K-Chinese',
#  'lmms-lab/M4-Instruct-Data',
#  'QuietImpostor/Claude-3-Opus-Claude-3.5-Sonnnet-9k',
#  'OpenFace-CQUPT/FaceCaption-15M',
#  'naijavoices/naijavoices-dataset',
#  'SmartGitiCorp/persian_tts',
#  'CaptionEmporium/midjourney-niji-1m-llavanext',
#  'visual-layer/imagenet-1k-vl-enriched',
#  'nothingiisreal/Claude-3-Opus-Instruct-15K',
#  'stanford-oval/ccnews',
#  'PleIAs/WTO-PDF',
#  'PleIAs/AMF-PDF',
#  'mrzjy/kaomoji_caption',
#  'watashihakobashi/ogiri',
#  'grider-withourai/nekopara-speech',
#  'airtrain-ai/fineweb-edu-fortified',
#  'kalomaze/Opus_Instruct_25k',
#  'Nopm/Opus_WritingStruct',
#  'argilla/magpie-ultra-v0.1',
#  'cfahlgren1/hub-stats',
#  'ThePioneer/japanese-photos',
#  'mlabonne/FineTome-100k',
#  'kms7530/ko-coco-bal',
#  'Vikhrmodels/Grounded-RAG-RU-v2',
#  'THUDM/LongWriter-6k',
#  'princeton-nlp/SWE-bench_Verified',
#  'Qingyun/llava_v1_5_fewshot_sft',
#  'allenai/OLMoE-mix-0924',
#  'Dusker/chinese-laws-pretrain',
#  'DataFog/medical-transcription-instruct',
#  'Team-ACE/ToolACE',
#  'Magpie-Align/Magpie-Llama-3.1-Pro-MT-500K-v0.1',
#  'ai-lab/MBD-mini',
#  'CaptionEmporium/flickr-megalith-10m-internvl2-multi-caption',
#  'gaianet/learn-rust',
#  'Joon007/science-feedback',
#  'allganize/RAG-Evaluation-Dataset-JA',
#  'vidore/colpali_train_set',
#  'TommyChien/UltraDomain',
#  'lmarena-ai/PPE-Human-Preference-V1',
#  'channelcorp/KoMagpie-raw',
#  'wjbmattingly/catmus-qwen2-vl',
#  'allenai/multipref',
#  'HuggingFaceFV/finevideo',
#  'LooksJuicy/Chinese-Roleplay-Novel',
#  'DominiqueBrunato/TRACE-it_CALAMITA',
#  'LooksJuicy/Chinese-Emotional-Intelligence',
#  'homebrewltd/instruction-text-only-full',
#  'autonomousvision/PDM_Lite_Carla_LB2',
#  'homebrewltd/mixed-instruction-speech-whispervq-v3-full',
#  'opencsg/chinese-cosmopedia',
#  'mistralai/MM-MT-Bench',
#  'yeates/PromptfixData',
#  'BAAI/IndustryInstruction',
#  'reach-vb/gguf-stats',
#  'davanstrien/ufo-ColPali',
#  'llm-lab/TuringQ',
#  'RANEPA-ai/SLAVA-OpenData-2800-v1',
#  'Maple728/Time-300B',
#  'TIGER-Lab/WebInstructFull',
#  'k-mktr/improved-flux-prompts-photoreal-portrait',
#  'nguyendv02/ViMD_Dataset',
#  'LiveXiv/LiveXiv',
#  'openbmb/VisRAG-Ret-Train-In-domain-data',
#  'meghas/fact_check_data',
#  'princeton-nlp/prolong-data-512K',
#  'argilla-warehouse/apigen-synth-trl',
#  'LLM360/TxT360',
#  'Sin2pi/JA_audio_EN_text_tedx_18k',
#  'rombodawg/Everything_Instruct_Multilingual',
#  'big-banyan-tree/BBT_CommonCrawl_2024',
#  'replit/agent-challenge',
#  'litagin/Galgame_Speech_ASR_16kHz',
#  'AntiplagiatCompany/CL4Lang',
#  'Cartinoe5930/web_text_synthetic_dataset_50k',
#  'dmis-lab/ChroKnowBench',
#  'Gryphe/Sonnet3.5-SlimOrcaDedupCleaned-20k',
#  'lt-asset/collu-bench',
#  'microsoft/TemporalBench',
#  'ChuGyouk/CompositionalGSM_augmented',
#  'AIML-TUDA/CLEVR-Sudoku',
#  'USTC-KnowledgeComputingLab/ElectrolyteBench',
#  'xhwl/cruxeval-x',
#  'ajrogier/llm-ideology-analysis',
#  'sam-paech/gutenbergs_1_2_3_antislop-dpo',
#  'z-hb/OpenSatMap',
#  'THUDM/LongReward-10k',
#  'united-we-care/United-Syn-Med',
#  'juliozhao/DocSynth300K',
#  'mertcobanov/animals',
#  'OpenDFM/MobA-MobBench',
#  'takara-ai/FloodNet_2021-Track_2_Dataset_HF',
#  'baijs/AudioSetCaps',
#  'Laxhar/danbooru_4M_pixel_resort',
#  'CohereForAI/m-ArenaHard',
#  'twodgirl/suppress-layers-in-sd3.5',
#  'yale-nlp/M3SciQA',
#  'ClovenDoug/150k_keyphrases_labelled',
#  'AlidarAsvarov/lez-rus-books',
#  'pls2000/pixiv20161029_20241026_monthly_rank_1_50',
#  'Pankaj8922/Text-corp',
#  'OALL/ALRAGE-Benchmark-sprint-results',
#  'ylacombe/globe_processed',
#  'DN-Erazora/ShinkaiGAN_Dataset',
#  'asigalov61/South-Park',
#  'DeepNLP/Human-Preferences-Alignment-KTO-Dataset-AI-Services-Genuine-User-Reviews',
#  'AIDX-ktds/ko_leaderboard',
#  'hpprc/aozora-yomi',
#  'nyuuzyou/ppt4web',
#  'Reza8848/AAAR-1.0',
#  'MilaWang/SpatialEval',
#  'asigalov61/Pub-Piano-MIDI-Dataset',
#  'YueDataset/RefRef',
#  'StarQuestLab/oxford-iiit-pet',
#  'UCLNLP/adversarial_qa',
#  'Yale-LILY/aeslc',
#  'nwu-ctext/afrikaans_ner_corpus',
#  'allenai/ai2_arc',
#  'google/air_dialogue',
#  'fancyzhx/amazon_polarity',
#  'defunct-datasets/amazon_us_reviews',
#  'legacy-datasets/ami',
#  'facebook/anli',
#  'deepmind/aqua_rat',
#  'halabi2016/arabic_speech_corpus',
#  'hsseinmz/arcd',
#  'facebook/asset',
#  'legacy-datasets/banking77',
#  'AI-Lab-Makerere/beans',
#  'nectec/best2009',
#  'FiscalNote/billsum',
#  'TheBritishLibrary/blbooks',
#  'ParlAI/blended_skill_talk',
#  'nyu-mll/blimp',
#  'barilan/blog_authorship_corpus',
#  'google/boolq',
#  'UFRGS/brwac',
#  'ryo0634/bsd_ja_en',
#  'legacy-datasets/c4',
#  'china-ai-law-challenge/cail2018',
#  'cam-cst/cbt',
#  'google-research-datasets/cfq',
#  'uoft-cs/cifar10',
#  'uoft-cs/cifar100',
#  'google-research-datasets/circa',
#  'google/civil_comments',
#  'tdiggelm/climate_fever',
#  'clinc/clinc_oos',
#  'clue/clue',
#  'jaredfern/codah',
#  'google/code_x_glue_cc_clone_detection_big_clone_bench',
#  'google/code_x_glue_cc_clone_detection_poj104',
#  'google/code_x_glue_cc_defect_detection',
#  'google/code_x_glue_ct_code_to_text',
#  'speechbrain/common_language',
#  'legacy-datasets/common_voice',
#  'hendrycks/competition_math',
#  'conceptnet5/conceptnet5',
#  'eriktks/conll2003',
#  'CFPB/consumer-finance-complaints',
#  'stanfordnlp/coqa',
#  'cornell-movie-dialog/cornell_movie_dialog',
#  'facebook/covost2',
#  'rishitdagli/cppe-5',
#  'stanfordnlp/craigslist_bargains',
#  'microsoft/crd3',
#  'theatticusproject/cuad-qa',
#  'community-datasets/definite_pronoun_resolution',
#  'community-datasets/disaster_response_messages',
#  'google-research-datasets/disfl_qa',
#  'thunlp/docred',
#  'ucinlp/drop',
#  'AUEB-NLP/ecthr_cases',
#  'SemEvalWorkshop/emo',
#  'dair-ai/emotion',
#  'facebook/empathetic_dialogues',
#  'iamollas/ethos',
#  'community-datasets/europa_eac_tm',
#  'Helsinki-NLP/europarl',
#  'mhardalov/exams',
#  'zalando-datasets/fashion_mnist',
#  'takala/financial_phrasebank',
#  'ethz/food101',
#  'GEM/gem',
#  'community-datasets/generics_kb',
#  'nyu-mll/glue',
#  'google-research-datasets/go_emotions',
#  'Efstathios/guardian_authorship',
#  'ImperialCollegeLondon/health_fact',
#  'SemEvalWorkshop/hyperpartisan_news_detection',
#  'iapp/iapp_wiki_qa_squad',
#  'ai4bharat/indic_glue',
#  'indonlp/indonlu',
#  'thu-coai/kd_conv_with_kb',
#  'Helsinki-NLP/kde4',
#  'facebook/kilt_tasks',
#  'facebook/kilt_wikipedia',
#  'klue/klue',
#  'inmoonlight/kor_hate',
#  'kakaobrain/kor_nli',
#  'facebook/lama',
#  'cimec/lambada',
#  'coastalcph/lex_glue',
#  'openslr/librispeech_asr',
#  'lince-benchmark/lince',
#  'keithito/lj_speech',
#  'billion-word-benchmark/lm1b',
#  'cis-lmu/m_lama',
#  'deepmind/math_dataset',
#  'allenai/math_qa',
#  'UCSD26/medical_dialog',
#  'apple/mkqa',
#  'microsoft/ms_marco',
#  'levow/msra_ner',
#  'IWSLT/mt_eng_vietnamese',
#  'nyu-mll/multi_nli',
#  'pfb30/multi_woz_v22',
#  'deepmind/narrativeqa',
#  'google-research-datasets/nq_open',
#  'malmaud/onestop_qa',
#  'Helsinki-NLP/open_subtitles',
#  'allenai/openbookqa',
#  'oscar-corpus/oscar',
#  'google-research-datasets/paws',
#  'peixiang/pec',
#  'peoples-daily-ner/peoples_daily_ner',
#  'deepmind/pg19',
#  'ybisk/piqa',
#  'ncbi/pubmed',
#  'qiaojin/PubMedQA',
#  'allenai/qasc',
#  'allenai/qasper',
#  'quora-competitions/quora',
#  'ehovy/race',
#  'mbien/recipe_nlg',
#  'kdexd/red_caps',
#  'webis/tldr-17',
#  'ucirvine/reuters21578',
#  'allenai/ropes',
#  'Samsung/samsum',
#  'kuznetsoffandrey/sberquad',
#  'airesearch/scb_mt_enth_2020',
#  'google-research-datasets/schema_guided_dstc8',
#  'armanc/scientific_papers',
#  'allenai/scifact',
#  'allenai/sciq',
#  'kyunghyuncho/search_qa',
#  'ucirvine/sms_spam',
#  'stanfordnlp/snli',
#  'allenai/social_bias_frames',
#  'google/speech_commands',
#  'xlangai/spider',
#  'crux82/squad_it',
#  'KorQuAD/squad_kor_v1',
#  'KorQuAD/squad_kor_v2',
#  'stanfordnlp/sst',
#  'PhilipMay/stsb_multi_mt',
#  'megagonlabs/subjqa',
#  'ufldl-stanford/svhn',
#  'allenai/swag',
#  'community-datasets/swahili_news',
#  'rcds/swiss_judgment_prediction',
#  'community-datasets/tashkeela',
#  'google-research-datasets/taskmaster2',
#  'Helsinki-NLP/tatoeba',
#  'tmu-nlp/thai_toxicity_tweet',
#  'EleutherAI/pile',
#  'karpathy/tiny_shakespeare',
#  'CogComp/trec',
#  'mandarjoshi/trivia_qa',
#  'savasy/ttc4900',
#  'fthbrmnby/turkish_product_reviews',
#  'cardiffnlp/tweet_eval',
#  'google-research-datasets/tydiqa',
#  'CSTR-Edinburgh/vctk',
#  'hltcoe/weibo_ner',
#  'bea2019st/wi_locness',
#  'CUHK-CSE/wider_face',
#  'google/wiki40b',
#  'michaelauli/wiki_bio',
#  'facebook/wiki_dpr',
#  'microsoft/wiki_qa',
#  'unimelb-nlp/wikiann',
#  'Salesforce/wikisql',
#  'allenai/winogrande',
#  'wmt/wmt14',
#  'wmt/wmt19',
#  'cambridgeltl/xcopa',
#  'google/xquad',
#  'EdinburghNLP/xsum',
#  'google/xtreme',
#  'community-datasets/yahoo_answers_topics',
#  'fancyzhx/yelp_polarity',
#  'AI-Sweden/SuperLim',
#  'Abirate/english_quotes',
#  'adorkin/extended_tweet_emojis',
#  'AlekseyKorshuk/comedy-scripts',
#  'Babelscape/wikineural',
#  'CAiRE/ASCEND',
#  'Nexdata/accented_english',
#  'DiFronzo/Human_Activity_Recognition',
#  'Emanuel/UD_Portuguese-Bosque',
#  'Fraser/dream-coder',
#  'GEM/ART',
#  'GEM/totto',
#  'GEM/wiki_auto_asset_turk',
#  'GonzaloA/fake_news',
#  'Helsinki-NLP/tatoeba_mt',
#  'KTH/nst',
#  'NbAiLab/norwegian_parliament',
#  'Paul/hatecheck',
#  'PaulLerner/viquae_wikipedia',
#  'PlanTL-GOB-ES/SQAC',
#  'PlanTL-GOB-ES/cantemist-ner',
#  'SetFit/20_newsgroups',
#  'SetFit/ag_news',
#  'SetFit/emotion',
#  'SetFit/go_emotions',
#  'SetFit/hate_speech_offensive',
#  'SetFit/sst2',
#  'SetFit/sst5',
#  'SetFit/subj',
#  'SetFit/tweet_sentiment_extraction',
#  'SoLID/shellcode_i_a32',
#  'SocialGrep/one-million-reddit-confessions',
#  'Tevatron/wikipedia-nq-corpus',
#  'ai4bharat/samanantar',
#  'albertvillanova/legal_contracts',
#  'albertvillanova/tests-raw-jsonl',
#  'alistvt/coqa-stories',
#  'andstor/smart_contracts',
#  'maastrichtlawtech/bsard',
#  'bavard/personachat_truecased',
#  'bazinga/bazinga',
#  'bigscience/P3',
#  'bs-modeling-metadata/c4-en-html-with-metadata',
#  'castorini/afriberta-corpus',
#  'ccdv/arxiv-classification',
#  'ccdv/arxiv-summarization',
#  'ccdv/cnn_dailymail',
#  'ccdv/govreport-summarization',
#  'clips/mfaq',
#  'clips/mqa',
#  'csebuetnlp/xlsum',
#  'dalle-mini/open-images',
#  'dynabench/dynasent',
#  'espejelomar/code_search_net_python_10000_examples',
#  'facebook/multilingual_librispeech',
#  'flax-sentence-embeddings/stackexchange_math_jsonl',
#  'gabtan99/pex-conversations',
#  'gpt3mix/sst2',
#  'gsarti/clean_mc4_it',
#  'gsarti/flores_101',
#  'hf-internal-testing/librispeech_asr_dummy',
#  'huggingartists/kendrick-lamar',
#  'huggingartists/mf-doom',
#  'huggingartists/young-thug',
#  'iarfmoose/qa_evaluator',
#  'iarfmoose/question_generator',
#  'imvladikon/hebrew_speech_kan',
#  'jfrenz/legalglue',
#  'jgammack/SAE-door-abstracts',
#  'jglaser/binding_affinity',
#  'jsfactory/mental_health_reddit_posts',
#  'kiyoung2/aistage-mrc',
#  'lara-martin/Scifi_TV_Shows',
#  'lewtun/drug-reviews',
#  'lewtun/github-issues',
#  'limjiayi/hateful_memes_expanded',
#  'liweili/c4_200m',
#  'lukesjordan/worldbank-project-documents',
#  'luozhouyang/dureader',
#  'codeparrot/codeparrot-clean',
#  'maydogan/TRSAv1',
#  'mishig/sample_images',
#  'ml6team/cnn_dailymail_nl',
#  'ml6team/xsum_nl',
#  'mostol/wiktionary-ipa',
#  'mozilla-foundation/common_voice_8_0',
#  'nateraw/fairface',
#  'ncduy/mt-en-vi',
#  'nferruz/UR50_2021_04',
#  'nickmuchi/trade-the-event-finance',
#  'nthngdy/ccnews_split',
#  'ought/raft',
#  'pile-of-law/pile-of-law',
#  'pmc/open_access',
#  'qanastek/ELRC-Medical-V2',
#  'qanastek/EMEA-V3',
#  'qanastek/WMT-16-PubMed',
#  'rahular/itihasa',
#  'sentence-transformers/embedding-training-data',
#  'sentence-transformers/reddit-title-body',
#  'shibing624/source_code',
#  'shivam/hindi_pib_processed',
#  'sil-ai/bloom-lm',
#  'solomonk/reddit_mental_health_posts',
#  'stas/openwebtext-10k',
#  'svakulenk0/qrecc',
#  'tau/scrolls',
#  'teven/stackexchange',
#  'tharindu/SOLID',
#  'transformersbook/codeparrot',
#  'turingbench/TuringBench',
#  'ucberkeley-dlab/measuring-hate-speech',
#  'unicamp-dl/mmarco',
#  'wikimedia/wikisource',
#  'winvoker/turkish-sentiment-analysis-dataset',
#  'z-uo/female-LJSpeech-italian',
#  'zapsdcn/citation_intent',
#  'zhoujun/hitab',
#  'huggan/anime-faces',
#  'nlpaueb/finer-139',
#  'google/xtreme_s',
#  'laion/relaion2B-en-research-safe',
#  'laion/relaion2B-multi-research-safe',
#  'Azu/Handwritten-Mathematical-Expression-Convert-LaTeX',
#  'McGill-NLP/feedbackQA',
#  'gigant/horse2zebra',
#  'ctheodoris/Genecorpus-30M',
#  'SetFit/amazon_reviews_multi_ja',
#  'SetFit/amazon_reviews_multi_zh',
#  'stjokerli/TextToText_wsc_seqio',
#  'Stanford/wikitablequestions',
#  'marsyas/gtzan',
#  'tomekkorbak/pile-curse-chunk-16',
#  'yhavinga/ccmatrix',
#  'Monash-University/monash_tsf',
#  'emrecan/nli_tr_for_simcse',
#  'nthngdy/oscar-small',
#  'Georgii/russianPoetry',
#  'blo05/cleaned_wiki_en_0-20',
#  'huggan/CelebA-faces-with-attributes',
#  'huggan/few-shot-dog',
#  'huggan/few-shot-art-painting',
#  'jamescalam/stoic-corpus',
#  'copenlu/fever_gold_evidence',
#  'marksverdhei/wordnet-definitions-en-2021',
#  'somosnlp-hackathon-2022/spanish-to-quechua',
#  'huggan/flowers-102-categories',
#  'SocialGrep/the-reddit-dataset-dataset',
#  'PolyAI/minds14',
#  'julien-c/impressionists',
#  'huggan/wikiart',
#  'chainyo/rvl-cdip-invoice',
#  'bible-nlp/biblenlp-corpus',
#  'skt/kobest_v1',
#  'huggingnft/cryptopunks',
#  'arampacha/rsicd',
#  'vicenteor/sbu_captions',
#  'vinaykudari/acled-information-extraction',
#  'patriziobellan/PET',
#  'mwong/fever-claim-related',
#  'Divyanshu/indicxnli',
#  'KevinZ/oLMpics',
#  'stepp1/tweet_emotion_intensity',
#  'bigscience-historical-texts/Open_Medieval_French',
#  'mteb/stackoverflowdupquestions-reranking',
#  'mteb/sickr-sts',
#  'enoriega/GENIA-Term-Corpus',
#  'ranjaykrishna/visual_genome',
#  'aharley/rvl_cdip',
#  'laion/clevr-webdataset',
#  'McGill-NLP/FaithDial',
#  'blinoff/kinopoisk',
#  'chrisjay/crowd-speech-africa',
#  'toxigen/toxigen-data',
#  'google/wit',
#  'wikimedia/wit_base',
#  'facebook/textvqa',
#  'Fhrozen/FSD50k',
#  'laion/laion-high-resolution',
#  'HugoLaurencon/libri_light',
#  'HuggingFaceM4/charades',
#  'pere/italian_tweets_500k',
#  'LIUM/tedlium',
#  'Team-PIXEL/rendered-wikipedia-english',
#  'tdros/corals',
#  'mteb/amazon_massive_intent',
#  'mwritescode/slither-audited-smart-contracts',
#  'wdc/products-2017',
#  'mteb/banking77',
#  'WorkInTheDark/FairytaleQA',
#  'Yoonseong/climatebert_factcheck',
#  'strombergnlp/nlpcc-stance',
#  'HuggingFaceM4/yttemporal180m',
#  'laion/laion2B-en-aesthetic',
#  'laion/laion1B-nolang-aesthetic',
#  'laion/laion-art',
#  'NLPC-UOM/sentence_alignment_dataset-Sinhala-Tamil-English',
#  'Voicemod/librispeech40',
#  'mteb/amazon_reviews_multi',
#  'mteb/amazon_polarity',
#  'mteb/tweet_sentiment_extraction',
#  'sileod/movie_recommendation',
#  'ganchengguang/resume_seven_class',
#  'mteb/sts22-crosslingual-sts',
#  'angie-chen55/python-github-code',
#  'LTCB/enwik8',
#  'lmqg/qg_koquad',
#  'limsc/fr-nfr-classification',
#  'BeIR/msmarco',
#  'BeIR/hotpotqa',
#  'Adapting/empathetic_dialogues_v2',
#  'ziq/depression_advice',
#  'momilla/flattened_contract_4tools',
#  'yoshitomo-matsubara/srsd-feynman_hard',
#  'AhmedSSabir/Japanese-wiki-dump-sentence-dataset',
#  'truthfulqa/truthful_qa',
#  'florentgbelidji/car-reviews',
#  'google/bigbench',
#  'Bingsu/Human_Action_Recognition',
#  'google/quickdraw',
#  'sil-ai/bloom-speech',
#  'speechcolab/gigaspeech',
#  'AlekseyKorshuk/erotic-books',
#  'SetFit/CR',
#  'stanfordnlp/sst2',
#  'demo-org/auditor_review',
#  'spencer/software_slacks',
#  'thu-coai/lccc',
#  'ITESM/embedded_faqs_medicare',
#  'angie-chen55/javascript-github-code',
#  'amanbawa96/jsonDataset',
#  'julien-c/kaggle-hugomathien-soccer',
#  'valurank/Adult-content-dataset',
#  'mounikaiiith/Telugu-Sarcasm',
#  'HuggingFaceM4/Stanford-Cars',
#  'Shayanvsf/pquad_public',
#  'Nexdata/Cantonese_Conversational_Speech_Data_by_Mobile_Phone_and_Voice_Recorder',
#  'iejMac/CLIP-Kinetics700',
#  'Nexdata/Far-filed_Noise_Speech_Data_in_Home_Environment_by_Mic-Array',
#  'Nexdata/Emotional_Video_Data',
#  'nateraw/parti-prompts',
#  'fever/feverous',
#  'stanfordnlp/concurrentqa',
#  'joelniklaus/brazilian_court_decisions',
#  'rkstgr/mtg-jamendo',
#  'HuggingFaceM4/VQAv2',
#  'codeparrot/codecomplex',
#  'Nexdata/Human_Facial_Skin_Defects_Data',
#  'pfin123/hindi-aggregated',
#  'knkarthick/dialogsum',
#  'christopher/rosetta-code',
#  'launch/open_question_type',
#  'knkarthick/samsum',
#  'kensho/spgispeech',
#  'codeparrot/github-code-clean',
#  'madao33/new-title-chinese',
#  'zh-plus/tiny-imagenet',
#  'benschill/brain-tumor-collection',
#  'FIdo-AI/ua-news',
#  'nreimers/reddit_question_best_answers',
#  'codeparrot/xlcost-text-to-code',
#  'Zaib/java-vulnerability',
#  'elihoole/asrs-aviation-reports',
#  'demelin/moral_stories',
#  'hita/social-behavior-emotions',
#  'naver-clova-ix/cord-v1',
#  'nreimers/reddit_question_best_answers_langs',
#  'rajistics/indian_food_images',
#  'tner/mit_movie_trivia',
#  'tner/mit_restaurant',
#  'jvanz/portuguese_sentiment_analysis',
#  'ceyda/fashion-products-small',
#  'Muennighoff/xwinograd',
#  'clapika2010/infotab',
#  'naver-clova-ix/cord-v2',
#  'naver-clova-ix/synthdog-ja',
#  'joelniklaus/mapa',
#  'FinanceInc/auditor_sentiment',
#  'Artificio/WikiArt',
#  'bhadresh-savani/photo-to-cartoon',
#  'ttxy/emotion',
#  'kiddothe2b/contract-nli',
#  'psyche/synonyms_ko',
#  'okite97/news-data',
#  'Aimlab/Sentiment-Analysis-Roman-Urdu',
#  'davanstrien/pytorchmodelmetadata',
#  'jordiae/exebench',
#  'AI-Growth-Lab/patents_claims_1.5m_traim_test',
#  'joelniklaus/lextreme',
#  'ziwenyd/transcoder-geeksforgeeks',
#  'daekeun-ml/naver-news-summarization-ko',
#  'Corran/pexelvideos',
#  'owaiskha9654/PubMed_MultiLabel_Text_Classification_Dataset_MeSH',
#  'Bingsu/laion2B-multi-korean-subset',
#  'rungalileo/medical_transcription_40',
#  'snoop2head/enron_aeslc_emails',
#  'NX2411/AIhub-korean-speech-data-large',
#  'podbilabs/synthdog-podbi-pl',
#  'nielsr/docvqa_1200_examples_donut',
#  'dali-does/clevr-math',
#  'pcuenq/oxford-pets',
#  'scikit-learn/churn-prediction',
#  'hoskinson-center/proof-pile',
#  'SLPL/syntran-fa',
#  'UCL-DARK/ludwig',
#  'juletxara/visual-spatial-reasoning',
#  'laion/aesthetics_v2_4.75',
#  'RUCAIBox/Story-Generation',
#  'allenai/nllb',
#  'Bingsu/zeroth-korean',
#  'iohadrubin/wikitext-103-raw-v1',
#  'AhmedSSoliman/CodeXGLUE-CONCODE',
#  'GateNLP/broad_twitter_corpus',
#  'sepidmnorozy/Uyghur_sentiment',
#  'sepidmnorozy/Cantonese_sentiment',
#  'sepidmnorozy/Korean_sentiment',
#  'sepidmnorozy/Vietnamese_sentiment',
#  'MLCommons/peoples_speech',
#  'laion/aesthetics_v2_4.5',
#  'allenai/real-toxicity-prompts',
#  'ariesutiono/entailment-bank-v3',
#  'tyqiangz/multilingual-sentiments',
#  'csebuetnlp/BanglaNMT',
#  'harshitkaran/Hindi',
#  'masakhane/mafand',
#  'RCC-MSU/collection3',
#  'ai-forever/Peter',
#  'kakaobrain/coyo-700m',
#  'iejMac/CLIP-WebVid',
#  'ShapeNet/ShapeNetSem-archive',
#  'yuntian-deng/im2latex-100k',
#  'hf-internal-testing/diffusers-images',
#  'demo-org/diabetes',
#  'ShapeNet/shapenetcore-glb',
#  'fusing/wikiart_captions',
#  'SamAct/medium_cleaned',
#  'bigbio/biosses',
#  'priyank-m/chinese_text_recognition',
#  'Leli1024/Race-processed',
#  'priyank-m/IAM_words_text_recognition',
#  'zeroshot/twitter-financial-news-topic',
#  'jonathanli/law-stack-exchange',
#  'ai-forever/school_notebooks_RU',
#  'pysentimiento/spanish-tweets',
#  'cannlytics/cannabis_results',
#  'opentargets/clinical_trial_reason_to_stop',
#  'dclure/laion-aesthetics-12m-umap',
#  'ntcuong777/ubuntu_dialogue_corpus_train',
#  'lambdalabs/pokemon-blip-captions',
#  'mrmoor/cyber-threat-intelligence',
#  'Bingsu/openwebtext_20p',
#  'psyche/korean_idioms',
#  'skytnt/fbanimehq',
#  'Gustavosta/Stable-Diffusion-Prompts',
#  'rajistics/electricity_demand',
#  'TheGreatRambler/mm2_user',
#  'yerevann/coco-karpathy',
#  'kejian/codesearchnet-python-pep8-v1',
#  'kejian/codesearchnet-python-raw-457k',
#  'THUDM/humaneval-x',
#  'nlp-guild/medical-data',
#  'yuntian-deng/im2ly',
#  'melismeric/spotify_song_album_covers',
#  'biomegix/soap-notes',
#  'detection-datasets/fashionpedia',
#  'detection-datasets/fashionpedia_4_categories',
#  'bccnf/NER-portugues-shuffled',
#  'dbal0503/Bundesliga',
#  'ashraq/esc50',
#  'eliwill/Stoic-dataset',
#  'marcmaxmeister/unitarian-universalist-sermons',
#  ...]

# %%
def create_outputdir(dir_name:str):
    '''
    Parameters:
    dir_name (int): Name of the folder to store output files.

    Returns:
    Creates folder in the current directory if does not exist.
    '''
    # current_dir_path= Path.cwd()
    # Create the directory
    try:
        directory = Path(dir_name)
        directory.mkdir(parents=True, exist_ok=True)
        
        return os.path.abspath(dir_name)   
        # return (f"Directory '{dir_name}' created successfully",dir_name)
        # print(f"Directory created or already exists at: {directory.resolve()}")
   
    except PermissionError:
        return(f"Permission denied: Unable to create '{dir_name}'.")
    except Exception as e:
        return(f"An error occurred: {e}")

# %%
def setup_logging(log_file: str, log_level: int = logging.INFO):
    """
    Set up logging configuration.

    Parameters:
    log_file (str): The filename for the log file.
    log_level (int): The logging level. Default is logging.INFO.

    Example:
    >>> setup_logging('my_log.log', logging.DEBUG)
    """
    # Create a logger
    logger = logging.getLogger()
    logger.setLevel(log_level)

    # Create a file handler that appends to the log file
    file_handler = logging.FileHandler(log_file)  # Default mode is 'a' (append)
    
    # Create a logging format
    formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
    file_handler.setFormatter(formatter)

    # Add the file handler to the logger
    logger.addHandler(file_handler)

# %%
def fetch_croissant_metadata(output_dir:str, log_file:str):
    
    #calling previous functions
    data_id = get_datasetids_HF()
    outputpath=create_outputdir(output_dir)
    setup_logging(log_file)
    
    first_20_items = data_id[:20]
    
    # Write each item to a separate file
    for i, data_id in enumerate(first_20_items):
    # for i in data_id:
        # Define the URL for the JSON-LD metadata
        url = f"https://huggingface.co/api/datasets/{data_id}/croissant/"
        # params = {'limit': 20,  # Limit the number of results to 20
        #           'sort': 'likes','offset': 0} 
        # Make a request to get the dataset metadata
        response = requests.get(url)
        filename = data_id.replace('/','_') +'.jsonld'
        # print(filename)
        output_filepath = os.path.join(outputpath , filename)
        print(output_filepath)
        # Defineing filename for JSON files
        file_name = data_id.replace('/','_')
    
        # Check if the request was successful
        if response.status_code == 200:
        # Save the JSON-LD metadata to a file
            with open(output_filepath, 'w', encoding="utf-8") as file:
                json_data = response.json()
                pretty_jsonld = json.dumps(json_data, indent=2, ensure_ascii=False)
                # The JSON-LD data to pretty print.
                file.write(pretty_jsonld)
                # file.write(response.text)
            print("Dataset metadata downloaded successfully! :", data_id)
            logging.info(f"Dataset metadata downloaded successfully for {data_id}: {response.status_code}")
            print('--------------------------------------------------------------------------------------------')
           
                
        else:
            print("Error: Unable to download the dataset metadata:", data_id)
            logging.error(f"Error fetching response {data_id}: {response.status_code}")
            print("Status code:", response.status_code, data_id)
            print('--------------------------------------------------------------------------------------------')

# %%
fetch_croissant_metadata('trial', 'api_hf.log')
# Out:
# C:\Users\Solanki\Repositories\BioHackathon24\trial\fka_awesome-chatgpt-prompts.jsonld
# Dataset metadata downloaded successfully! : fka/awesome-chatgpt-prompts
# --------------------------------------------------------------------------------------------
# C:\Users\Solanki\Repositories\BioHackathon24\trial\neuralwork_arxiver.jsonld
# Dataset metadata downloaded successfully! : neuralwork/arxiver
# --------------------------------------------------------------------------------------------
# C:\Users\Solanki\Repositories\BioHackathon24\trial\Spawning_PD12M.jsonld
# Dataset metadata downloaded successfully! : Spawning/PD12M
# --------------------------------------------------------------------------------------------
# C:\Users\Solanki\Repositories\BioHackathon24\trial\vikhyatk_lofi.jsonld
# Dataset metadata downloaded successfully! : vikhyatk/lofi
# --------------------------------------------------------------------------------------------
# C:\Users\Solanki\Repositories\BioHackathon24\trial\BAAI_Infinity-MM.jsonld
# Error: Unable to download the dataset metadata: BAAI/Infinity-MM
# Status code: 401 BAAI/Infinity-MM
# --------------------------------------------------------------------------------------------
# C:\Users\Solanki\Repositories\BioHackathon24\trial\GAIR_o1-journey.jsonld
# Dataset metadata downloaded successfully! : GAIR/o1-journey
# --------------------------------------------------------------------------------------------
# C:\Users\Solanki\Repositories\BioHackathon24\trial\marcelbinz_Psych-101.jsonld
# Dataset metadata downloaded successfully! : marcelbinz/Psych-101
# --------------------------------------------------------------------------------------------
# C:\Users\Solanki\Repositories\BioHackathon24\trial\amphion_Emilia-Dataset.jsonld
# Error: Unable to download the dataset metadata: amphion/Emilia-Dataset
# Status code: 401 amphion/Emilia-Dataset
# --------------------------------------------------------------------------------------------
# C:\Users\Solanki\Repositories\BioHackathon24\trial\neulab_PangeaInstruct.jsonld
# Error: Unable to download the dataset metadata: neulab/PangeaInstruct
# Status code: 400 neulab/PangeaInstruct
# --------------------------------------------------------------------------------------------
# C:\Users\Solanki\Repositories\BioHackathon24\trial\BAAI_Infinity-Instruct.jsonld
# Error: Unable to download the dataset metadata: BAAI/Infinity-Instruct
# Status code: 401 BAAI/Infinity-Instruct
# --------------------------------------------------------------------------------------------
# C:\Users\Solanki\Repositories\BioHackathon24\trial\ajibawa-2023_Software-Architecture.jsonld
# Dataset metadata downloaded successfully! : ajibawa-2023/Software-Architecture
# --------------------------------------------------------------------------------------------
# C:\Users\Solanki\Repositories\BioHackathon24\trial\wikimedia_wikipedia.jsonld
# Dataset metadata downloaded successfully! : wikimedia/wikipedia
# --------------------------------------------------------------------------------------------
# C:\Users\Solanki\Repositories\BioHackathon24\trial\HuggingFaceH4_ultrachat_200k.jsonld
# Dataset metadata downloaded successfully! : HuggingFaceH4/ultrachat_200k
# --------------------------------------------------------------------------------------------
# C:\Users\Solanki\Repositories\BioHackathon24\trial\allenai_dolma.jsonld
# Error: Unable to download the dataset metadata: allenai/dolma
# Status code: 400 allenai/dolma
# --------------------------------------------------------------------------------------------
# C:\Users\Solanki\Repositories\BioHackathon24\trial\mlabonne_orpo-dpo-mix-40k.jsonld
# Dataset metadata downloaded successfully! : mlabonne/orpo-dpo-mix-40k
# --------------------------------------------------------------------------------------------
# C:\Users\Solanki\Repositories\BioHackathon24\trial\upstage_dp-bench.jsonld
# Error: Unable to download the dataset metadata: upstage/dp-bench
# Status code: 400 upstage/dp-bench
# --------------------------------------------------------------------------------------------
# C:\Users\Solanki\Repositories\BioHackathon24\trial\nvidia_HelpSteer2.jsonld
# Dataset metadata downloaded successfully! : nvidia/HelpSteer2
# --------------------------------------------------------------------------------------------
# C:\Users\Solanki\Repositories\BioHackathon24\trial\wyu1_Leopard-Instruct.jsonld
# Dataset metadata downloaded successfully! : wyu1/Leopard-Instruct
# --------------------------------------------------------------------------------------------
# C:\Users\Solanki\Repositories\BioHackathon24\trial\Amod_mental_health_counseling_conversations.jsonld
# Dataset metadata downloaded successfully! : Amod/mental_health_counseling_conversations
# --------------------------------------------------------------------------------------------
# C:\Users\Solanki\Repositories\BioHackathon24\trial\nkp37_OpenVid-1M.jsonld
# Dataset metadata downloaded successfully! : nkp37/OpenVid-1M
# --------------------------------------------------------------------------------------------

# %%
# # Define a function to fetch metadata for a single dataset
# def fetch_metadata(data_id):
#     url = f"https://huggingface.co/api/datasets/{data_id}/croissant"
#     response = requests.get(url)
#     filename = data_id.replace('/', '_') + '.jsonld'
#     output_filepath = os.path.join(outputpath, filename)
    
#     if response.status_code == 200:
#         # Save the JSON-LD metadata to a file
#         with open(output_filepath, 'w', encoding="utf-8") as file:
#             # Loading the response in JSON format.
#             json_data = response.json()
#             pretty_jsonld = json.dumps(json_data, indent=2, ensure_ascii=False)
#             # The JSON-LD data to pretty print.
#             file.write(pretty_jsonld)
#         logging.info(f"Dataset metadata downloaded successfully for {data_id}: {response.status_code}")
#         return f"Success: {data_id}"
#     else:
#         logging.error(f"Error fetching response {data_id}: {response.status_code}")
#         return f"Error: {data_id} - {response.status_code}"

#     # Use ThreadPoolExecutor to fetch metadata in parallel
#     with ThreadPoolExecutor(max_workers=5) as executor:
#         future_to_id = {executor.submit(fetch_metadata, data_id): data_id for data_id in first_20_items}
        
#         for future in as_completed(future_to_id):
#             result = future.result()
#             print(result)

# # Example usage
# if __name__ == "__main__":
#     fetch_croissant_metadata('output_files_', 'log.txt')
